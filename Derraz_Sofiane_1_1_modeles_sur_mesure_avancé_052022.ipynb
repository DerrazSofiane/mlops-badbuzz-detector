# %% [markdown]
# <h1>Table des matières<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Présentation" data-toc-modified-id="Présentation-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Présentation</a></span></li><li><span><a href="#Import-des-librairies" data-toc-modified-id="Import-des-librairies-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import des librairies</a></span></li><li><span><a href="#Chargement-du-jeu-de-données" data-toc-modified-id="Chargement-du-jeu-de-données-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Chargement du jeu de données</a></span></li><li><span><a href="#Nettoyage-du-jeu-de-données" data-toc-modified-id="Nettoyage-du-jeu-de-données-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Nettoyage du jeu de données</a></span><ul class="toc-item"><li><span><a href="#Nettoyage-des-colonnes" data-toc-modified-id="Nettoyage-des-colonnes-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Nettoyage des colonnes</a></span></li><li><span><a href="#Nettoyage-des-doublons" data-toc-modified-id="Nettoyage-des-doublons-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Nettoyage des doublons</a></span></li></ul></li><li><span><a href="#Pré-traitement-des-données-textuelles" data-toc-modified-id="Pré-traitement-des-données-textuelles-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Pré-traitement des données textuelles</a></span><ul class="toc-item"><li><span><a href="#Sélection-d'un-échantillon" data-toc-modified-id="Sélection-d'un-échantillon-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Sélection d'un échantillon</a></span></li><li><span><a href="#Fonctions-de-nettoyage" data-toc-modified-id="Fonctions-de-nettoyage-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Fonctions de nettoyage</a></span></li><li><span><a href="#Automatisation-du-processus-de-nettoyage" data-toc-modified-id="Automatisation-du-processus-de-nettoyage-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Automatisation du processus de nettoyage</a></span></li><li><span><a href="#Lemmatisation" data-toc-modified-id="Lemmatisation-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Lemmatisation</a></span></li><li><span><a href="#Stemming" data-toc-modified-id="Stemming-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Stemming</a></span></li><li><span><a href="#Encoding" data-toc-modified-id="Encoding-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Encoding</a></span></li></ul></li><li><span><a href="#Séparation-du-jeu-de-données" data-toc-modified-id="Séparation-du-jeu-de-données-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Séparation du jeu de données</a></span></li><li><span><a href="#Tokenization" data-toc-modified-id="Tokenization-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Tokenization</a></span></li><li><span><a href="#Glove" data-toc-modified-id="Glove-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Glove</a></span></li><li><span><a href="#FastText" data-toc-modified-id="FastText-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>FastText</a></span></li><li><span><a href="#Fonctions-utiles" data-toc-modified-id="Fonctions-utiles-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Fonctions utiles</a></span></li><li><span><a href="#Baseline-SimpleRNN-avec-Glove" data-toc-modified-id="Baseline-SimpleRNN-avec-Glove-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Baseline SimpleRNN avec Glove</a></span><ul class="toc-item"><li><span><a href="#Baseline-:-SimpleRNN-+-Glove" data-toc-modified-id="Baseline-:-SimpleRNN-+-Glove-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Baseline : SimpleRNN + Glove</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-11.1.1"><span class="toc-item-num">11.1.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-11.1.2"><span class="toc-item-num">11.1.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-11.1.3"><span class="toc-item-num">11.1.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-11.1.4"><span class="toc-item-num">11.1.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-11.1.5"><span class="toc-item-num">11.1.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li><li><span><a href="#Baseline-SimpleRNN-+-Glove-+-Lemma" data-toc-modified-id="Baseline-SimpleRNN-+-Glove-+-Lemma-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Baseline SimpleRNN + Glove + Lemma</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-11.2.1"><span class="toc-item-num">11.2.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-11.2.2"><span class="toc-item-num">11.2.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-11.2.3"><span class="toc-item-num">11.2.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-11.2.4"><span class="toc-item-num">11.2.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-11.2.5"><span class="toc-item-num">11.2.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li><li><span><a href="#Baseline-:-SimpleRNN-+-Glove-+-stem" data-toc-modified-id="Baseline-:-SimpleRNN-+-Glove-+-stem-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Baseline : SimpleRNN + Glove + stem</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-11.3.1"><span class="toc-item-num">11.3.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-11.3.2"><span class="toc-item-num">11.3.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-11.3.3"><span class="toc-item-num">11.3.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-11.3.4"><span class="toc-item-num">11.3.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-11.3.5"><span class="toc-item-num">11.3.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li></ul></li><li><span><a href="#Baseline-SimpleRNN-avec-FastText" data-toc-modified-id="Baseline-SimpleRNN-avec-FastText-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Baseline SimpleRNN avec FastText</a></span><ul class="toc-item"><li><span><a href="#Baseline-:-SimpleRNN-+-FastText" data-toc-modified-id="Baseline-:-SimpleRNN-+-FastText-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Baseline : SimpleRNN + FastText</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-12.1.1"><span class="toc-item-num">12.1.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-12.1.2"><span class="toc-item-num">12.1.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-12.1.3"><span class="toc-item-num">12.1.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-12.1.4"><span class="toc-item-num">12.1.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultat-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultat-dans-un-tableau-12.1.5"><span class="toc-item-num">12.1.5&nbsp;&nbsp;</span>Sauvegarde des résultat dans un tableau</a></span></li></ul></li><li><span><a href="#Baseline-:-SimpleRNN-+-FastText-+-Lemma" data-toc-modified-id="Baseline-:-SimpleRNN-+-FastText-+-Lemma-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>Baseline : SimpleRNN + FastText + Lemma</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-12.2.1"><span class="toc-item-num">12.2.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-12.2.2"><span class="toc-item-num">12.2.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-12.2.3"><span class="toc-item-num">12.2.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-12.2.4"><span class="toc-item-num">12.2.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-12.2.5"><span class="toc-item-num">12.2.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li><li><span><a href="#Baseline-:-SimpleRNN-+-FastText-+-stem" data-toc-modified-id="Baseline-:-SimpleRNN-+-FastText-+-stem-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>Baseline : SimpleRNN + FastText + stem</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-12.3.1"><span class="toc-item-num">12.3.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-12.3.2"><span class="toc-item-num">12.3.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-12.3.3"><span class="toc-item-num">12.3.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-12.3.4"><span class="toc-item-num">12.3.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-12.3.5"><span class="toc-item-num">12.3.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li></ul></li><li><span><a href="#LSTM" data-toc-modified-id="LSTM-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>LSTM</a></span><ul class="toc-item"><li><span><a href="#LSTM-+-Glove" data-toc-modified-id="LSTM-+-Glove-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>LSTM + Glove</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-13.1.1"><span class="toc-item-num">13.1.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-13.1.2"><span class="toc-item-num">13.1.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-13.1.3"><span class="toc-item-num">13.1.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-13.1.4"><span class="toc-item-num">13.1.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-13.1.5"><span class="toc-item-num">13.1.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li><li><span><a href="#Prédiction-du-modèle" data-toc-modified-id="Prédiction-du-modèle-13.1.6"><span class="toc-item-num">13.1.6&nbsp;&nbsp;</span>Prédiction du modèle</a></span></li></ul></li><li><span><a href="#LSTM-+-Glove-+-Lemma" data-toc-modified-id="LSTM-+-Glove-+-Lemma-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>LSTM + Glove + Lemma</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-13.2.1"><span class="toc-item-num">13.2.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-13.2.2"><span class="toc-item-num">13.2.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-13.2.3"><span class="toc-item-num">13.2.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-13.2.4"><span class="toc-item-num">13.2.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-13.2.5"><span class="toc-item-num">13.2.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li><li><span><a href="#LSTM-+-Glove-+-stem" data-toc-modified-id="LSTM-+-Glove-+-stem-13.3"><span class="toc-item-num">13.3&nbsp;&nbsp;</span>LSTM + Glove + stem</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-13.3.1"><span class="toc-item-num">13.3.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-13.3.2"><span class="toc-item-num">13.3.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-13.3.3"><span class="toc-item-num">13.3.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-13.3.4"><span class="toc-item-num">13.3.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-13.3.5"><span class="toc-item-num">13.3.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li><li><span><a href="#LSTM-avec-FastText" data-toc-modified-id="LSTM-avec-FastText-13.4"><span class="toc-item-num">13.4&nbsp;&nbsp;</span>LSTM avec FastText</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-13.4.1"><span class="toc-item-num">13.4.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-13.4.2"><span class="toc-item-num">13.4.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-13.4.3"><span class="toc-item-num">13.4.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-13.4.4"><span class="toc-item-num">13.4.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegardes-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegardes-des-résultats-dans-un-tableau-13.4.5"><span class="toc-item-num">13.4.5&nbsp;&nbsp;</span>Sauvegardes des résultats dans un tableau</a></span></li></ul></li><li><span><a href="#LSTM-+-FastText-+-Lemma" data-toc-modified-id="LSTM-+-FastText-+-Lemma-13.5"><span class="toc-item-num">13.5&nbsp;&nbsp;</span>LSTM + FastText + Lemma</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-13.5.1"><span class="toc-item-num">13.5.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-13.5.2"><span class="toc-item-num">13.5.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-13.5.3"><span class="toc-item-num">13.5.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-13.5.4"><span class="toc-item-num">13.5.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-13.5.5"><span class="toc-item-num">13.5.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li><li><span><a href="#LSTM-+-FastText-+-stem" data-toc-modified-id="LSTM-+-FastText-+-stem-13.6"><span class="toc-item-num">13.6&nbsp;&nbsp;</span>LSTM + FastText + stem</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-13.6.1"><span class="toc-item-num">13.6.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-13.6.2"><span class="toc-item-num">13.6.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Visualisation-de-l'apprentissage" data-toc-modified-id="Visualisation-de-l'apprentissage-13.6.3"><span class="toc-item-num">13.6.3&nbsp;&nbsp;</span>Visualisation de l'apprentissage</a></span></li><li><span><a href="#Résultats-du-modèle" data-toc-modified-id="Résultats-du-modèle-13.6.4"><span class="toc-item-num">13.6.4&nbsp;&nbsp;</span>Résultats du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-13.6.5"><span class="toc-item-num">13.6.5&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li></ul></li><li><span><a href="#Bert" data-toc-modified-id="Bert-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Bert</a></span><ul class="toc-item"><li><span><a href="#Entrainement-du-modèle" data-toc-modified-id="Entrainement-du-modèle-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span>Entrainement du modèle</a></span></li><li><span><a href="#Évaluation-du-modèle" data-toc-modified-id="Évaluation-du-modèle-14.2"><span class="toc-item-num">14.2&nbsp;&nbsp;</span>Évaluation du modèle</a></span></li><li><span><a href="#Sauvegarde-des-résultats-dans-un-tableau" data-toc-modified-id="Sauvegarde-des-résultats-dans-un-tableau-14.3"><span class="toc-item-num">14.3&nbsp;&nbsp;</span>Sauvegarde des résultats dans un tableau</a></span></li></ul></li><li><span><a href="#Tensorboard" data-toc-modified-id="Tensorboard-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Tensorboard</a></span></li><li><span><a href="#Optimisation-des-hyperparamètres-pour-le-meilleur-modèle" data-toc-modified-id="Optimisation-des-hyperparamètres-pour-le-meilleur-modèle-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Optimisation des hyperparamètres pour le meilleur modèle</a></span></li><li><span><a href="#Comparaison-des-résultats" data-toc-modified-id="Comparaison-des-résultats-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Comparaison des résultats</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></div>

# %% [markdown]
# # Présentation
#
# Air Paradis veut créer un produit IA permettant d’anticiper les bad buzz sur les réseaux sociaux. Air Paradis veut un prototype d’un produit IA permettant de prédire le sentiment associé à un tweet.
#
# * Données : pas de données clients chez Air Paradis. Solution : utiliser des données Open Source.
# * Description des données : des informations sur les tweets (utilisateur ayant posté, contenu, moment du post) et un label binaire (tweet exprimant un sentiment négatif ou non).
#
# L'étude du sujet pourra être réalisée à travers les étapes suivantes :
# * Préparer un prototype fonctionnel du modèle. Le modèle envoie un tweet et récupère la prédiction de sentiment.
# * Préparer un support de présentation explicitant la méthodologie utilisée pour l’approche “modèle sur mesure avancé”.
#
# Voici un aperçu détaillé des étapes :
#
# **Suppression des URL et des adresses électroniques de chaque échantillon** — parce qu'ils n'ajouteront pas de valeur significative.
#
# **Suppression des signes de ponctuation** — sinon le modèle ne comprendra pas que "bon !" et "bon" signifient en fait la même chose.
#
# **On passe le texte en minuscules** — parce qu'on veut rendre le texte d'entrée aussi générique que possible et éviter que, par exemple, un "Bon" qui se trouve au début d'une phrase soit compris différemment du "bon" dans un autre échantillon.
#
# **Stemming/Lemmatisation** — Cette étape est facultative, mais pour la plupart des spécialistes des données, elle est considérée comme cruciale. On montrera au cours de ce notebook qu'elle n'est pas si importante pour obtenir de bons résultats. Le stemming (ou la stemmatisation) et la lemmatisation sont des tâches très similaires, les deux cherchent à extraire les mots racines de chaque mot d'une phrase du corpus de données.
#
# La lemmatisation renvoie généralement des mots valides (qui existent), tandis que le stemming renvoie (la plupart du temps) des mots plus courts, c'est pourquoi la lemmatisation est plus utilisée dans les implémentations du monde réel. Voici comment fonctionnent les lemmatiseurs et les stemmatiseurs : supposons qu'on veuille trouver la racine de <code>caring</code> : <code>Caring</code> -> lemmatisation -> <code>Care</code>. D'un autre côté : <code>Caring</code> -> stemming -> <code>Car</code>.
#
# **Transformation d'un ensemble de données (texte) en tenseurs numériques** — On parle généralement de vectorisation, ou de tokenisation. Les modèles d'apprentissage profond (deep learning) ne prennent pas de texte brut en entrée : ils ne travaillent qu'avec des tenseurs numériques, c'est pourquoi cette étape n'est pas négociable.
#
# Il existe de multiples façons de procéder ; par exemple, si on compte utiliser un modèle ML classique (pas DL), on doit absolument opter pour CountVectorizer, TFIDF Vectorizer ou simplement l'approche de base : Bag-Of-Words. Cependant, si on a l'intention de mettre en œuvre l'apprentissage profond, la meilleure façon de procéder est de transformer les données textuelles (qui peuvent être comprises comme des séquences de mots ou des séquences de caractères) en vecteurs à virgule flottante de faible dimension.
#
# C'est ainsi que les données sont préparées pour que la machine puisse les comprendre.
#
# **Prolongement de mots (word embedding)** - Le plongement de mot est une méthode qui permet de rapprocher les mots similaires entre eux. Nous verrons la méthode GloVe et la méthode FastText.
#
# L'étape suivante consiste à entraîner des modèles. On y verra plusieurs modèles :
# * Modèle de base Keras **SimpleRNN** (Recurrent Neural Networks), sur lequel on se basera pour évaluer les performances des modèles plus avancés.
# * Modèle avancé **LSTM** (Long Short-Term Memory).
# * Modèle avancé **BERT** (Bidirectional Encoder Representations from Transformers). Conçu par Google.
#
# Un tableau comparatif des résultats sera généré à la fin.

# %% [markdown]
# https://docs.microsoft.com/fr-fr/azure/cognitive-services/language-service/sentiment-opinion-mining/overview

# %% [markdown]
# <b>TO DO:</b>
# * Charger les données
# * Nettoyer les colonnes (garder les tweets et le target)
# * Sample du jeu de données
# * Fonction de nettoyage de tweet (minuscule, caractères spéciaux, liens, hashtag, mentions, accents, caractères non alphanumériques)
# * Stemming, lemmatisation, ou rien du tout
# * Split train test 80/20
# * Tokenisation
# * Préparer des fonctions pour le plongement de mots (word embedding)
#     - Fasttext
#     - Glove
# * Modèle de base Keras
# * Faire une fonction pour la matrice de confusion
# * Faire une fonction pour la courbe d'apprentissage (pour surveiller le surapprentissage)
# * Stocker dans une dataframe :
#     - score ROC
#     - précision (diminuer les faux positif) ou accuracy
#     - temps d'entraînement
# * Tester un modèle Keras avec embedding et couche LSTM
#     - Optimisation d'au moins un hyperparamètre du modèle à l'aide de Keras tuner
#     https://keras.io/keras_tuner/
# * Tester modèle BERT
# * Tableau comparatif des résultats

# %% [markdown]
# # Import des librairies

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from numpy import asarray
from numpy import zeros

from nltk.tokenize import TweetTokenizer
from nltk.stem.snowball import SnowballStemmer

from spacy.tokenizer import Tokenizer
from spacy.lang.en import English
import spacy

import gensim
import pickle

import contractions

import re
import os
from datetime import datetime
from time import time

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report
import itertools

import tensorflow as tf
from tensorflow.keras.layers import SimpleRNN, LSTM, Bidirectional
# %load_ext tensorboard

from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding, LSTM, GlobalMaxPool1D, Flatten
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from keras.callbacks import ReduceLROnPlateau
from keras.models import load_model

from tensorflow.keras.layers import Dropout, SpatialDropout1D
from tensorflow.keras import regularizers
from tensorflow import keras
import keras_tuner as kt

from kerastuner.tuners import RandomSearch

from transformers import logging, AutoTokenizer, TFAutoModel

import matplotlib.pyplot as plt

# %% [markdown]
# # Chargement du jeu de données
# https://www.kaggle.com/kazanova/sentiment140

# %%
twitter_data = pd.read_csv(
    "training.1600000.processed.noemoticon.csv",
    encoding="ISO-8859-1",
    header=None
)

twitter_data
# Out:
#          0           1                             2         3  \
# 0        0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1        0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2        0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3        0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4        0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...     ..         ...                           ...       ...
# 1599995  4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996  4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997  4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998  4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999  4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                        4                                                  5
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# ...

# %%
twitter_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   0       1600000 non-null  int64
#  1   1       1600000 non-null  int64
#  2   2       1600000 non-null  object
#  3   3       1600000 non-null  object
#  4   4       1600000 non-null  object
#  5   5       1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %% [markdown]
# Le jeu de données contient 1 600 000 tweets extraits à l'aide de l'API de Twitter. Les tweets ont été annotés (0=négatif, 2=neutre, 4=positif) et peuvent être utilisés pour détecter les sentiments.
#
# Nous pouvons remarquer d'entrée de jeu qu'il n'y a pas de valeurs manquantes.
#
# Le jeu de données date de 2009 et provient d'un sujet d'étude de Stanford :
#
# <b>_Go, A., Bhayani, R. and Huang, L., 2009. Twitter sentiment classification using distant supervision. CS224N Project Report, Stanford, 1(2009), p.12._</b>

# %% [markdown]
# # Nettoyage du jeu de données

# %% [markdown]
# ## Nettoyage des colonnes
#
# Le jeu de données ne contient pas de nom de colonne. Ca sera à nous de les nommer. Voici quelle colonne correspond à quelle donnée :
# * <b>La première colonne</b> est la cible de notre étude. À savoir : si le tweet est positif ou négatif. Si le commentaire est négatif, alors la valeur est 0. Si le commentaire est positif, la valeur est 4.
# * <b>La deuxième colonne</b> est le numéro d'identification du tweet.
# * <b>La troisième colonne</b> est la date de publication du tweet.
# * <b>La quatrième colonne</b> La requête (lyx). S'il n'y a pas de requête, cette valeur est NO_QUERY. La colonne n'a qu'une seule valeur et sera donc inutile pour notre étude. Nous pourrons l'ignorer.
# * <b>La quatrième colonne</b> est le nom de l'utilisateur du tweet.
# * <b>La cinquième colonne</b> est le contenu du tweet.
#
# Les colonnes les plus importantes pour notre étude sera la première colonne, nous informant si le tweet a un sentiment positif ou négatif, et la dernière colonne : le tweet en lui même.
#
# Les noms originels des colonnes sont disponibles sur le lien suivant : https://www.kaggle.com/kazanova/sentiment140.
# Nous allons nommer les colonnes comme décrit sur la description originelle du jeu de données.

# %%
twitter_data = twitter_data.rename(
    columns={
        0: "target",
        1: "ids",
        2: "date",
        3: "flag",
        4: "user",
        5: "text"
    })

twitter_data
# Out:
#          target         ids                          date      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %% [markdown]
# Conservons maintenant uniquement les colonnes qui nous serons utiles : <b>target</b> pour la polarité du tweet et <b>text</b> pour le contenu du tweet.

# %%
twitter_data = twitter_data[["target", "text"]]
twitter_data
# Out:
#          target                                               text
# 0             0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1             0  is upset that he can't update his Facebook by ...
# 2             0  @Kenichan I dived many times for the ball. Man...
# 3             0    my whole body feels itchy and like its on fire
# 4             0  @nationwideclass no, it's not behaving at all....
# ...         ...                                                ...
# 1599995       4  Just woke up. Having no school is the best fee...
# 1599996       4  TheWDB.com - Very cool to hear old Walt interv...
# 1599997       4  Are you ready for your MoJo Makeover? Ask me f...
# 1599998       4  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999       4  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 2 columns]

# %% [markdown]
# ## Nettoyage des doublons

# %%
len_before = len(twitter_data)
print("Nombre de lignes avant suppression des doublons :", len_before)

twitter_data = twitter_data.drop_duplicates()

len_after = len(twitter_data)
print("Nombre de lignes après suppression des doublons :", len_after)
print("Doublons supprimés :", len_before-len_after)
# Out:
# Nombre de lignes avant suppression des doublons : 1600000
# Nombre de lignes après suppression des doublons : 1583691
# Doublons supprimés : 16309

# %% [markdown]
# # Pré-traitement des données textuelles

# %% [markdown]
# ## Sélection d'un échantillon
#
# Afin de rendre le calcul moins éprouvant pour l'ordinateur, nous allons nous contenter d'un échantillon de chaque valeur de target.

# %%
twitter_data["target"].value_counts()
# Out:
# 4    793506
# 0    790185
# Name: target, dtype: int64

# %% [markdown]
# Nous avons bien un label binaire : 0 (négatif) et 4 (positif). Sélectionnons 4000 de chaque.

# %%
n_sample = 4000

twitter_data_neg = twitter_data[twitter_data["target"] == 0]
twitter_data_pos = twitter_data[twitter_data["target"] == 4]

twitter_data_sample = pd.concat([
    twitter_data_neg[:n_sample],
    twitter_data_pos[:n_sample]])

twitter_data_sample
# Out:
#         target                                               text
# 0            0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1            0  is upset that he can't update his Facebook by ...
# 2            0  @Kenichan I dived many times for the ball. Man...
# 3            0    my whole body feels itchy and like its on fire
# 4            0  @nationwideclass no, it's not behaving at all....
# ...        ...                                                ...
# 804003       4  after smoking for 16 years , i have now not ha...
# 804004       4                 @libbyoliver Hes my Ravin Rabbid!
# 804005       4  And I'm quite chuffed: Finally shelled out the...
# 804006       4  u would never think that three 15 year olds wh...
# 804007       4  back to the grind of a 9-5, only for three day...
#
# [8000 rows x 2 columns]

# %%
twitter_validation_set = pd.concat([
    twitter_data_neg[10000:10800],
    twitter_data_pos[10000:10800]])

twitter_validation_set
# Out:
#         target                                               text
# 10025        0  @Violet_Crush Sorry to hear that  But at least...
# 10026        0                   I broke the vibrate on my fone.
# 10027        0  Race was good! Ran better than last time. Didn...
# 10028        0  @IngaLeonora I just got home but really didn't...
# 10029        0                                   @emkins i KNOW!
# ...        ...                                                ...
# 810817       4           @rossmills you need a cosplay sweatshop
# 810818       4  @GreenYogurt lol, my dog's toys? all single. i...
# 810819       4  @JennyErikson HItting the to do list hard.  Sh...
# 810820       4  Drinking a smoothie without a straw = smoothie...
# 810821       4  @lukeayresryan Fucking well done!!!!!!!!!!!! I...
#
# [1600 rows x 2 columns]

# %%
twitter_data_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 0 to 804007
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  8000 non-null   int64
#  1   text    8000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 187.5+ KB

# %% [markdown]
# ## Fonctions de nettoyage
#
# https://stackoverflow.com/questions/61919670/how-nltk-tweettokenizer-different-from-nltk-word-tokenize
#
# Certains caractères ne relèvent d'aucune pertinence pour l'analyse des sentiments. Comme par exemple les liens, les hashtag, les mentions, accents et caractères non alphanumériques.
#
# On peut également transformer les majuscules en minuscule.
#
# Ainsi, le jeu de données sera allégé et prêt à être interprété sans encombre par l'IA.

# %%
text_sample = twitter_data_sample["text"].iloc[0]
text_sample
# Out:
# "@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"

# %% [markdown]
# Il y a un ici un ordre de nettoyage à respecter. En effet, pour détecter une mention par exemple, il nous faut détecter la présence du caractère <code>@</code> (qui est un caractère non alphanumérique), suivis du nom de l'utilisateur mentionné. Or, si nous supprimons dans un premier temps les caractères non alphanumériques, il nous sera impossible de détecter les mentions.
#
# Ici, nous un bon exemple de tweet à nettoyer, avec une mention, un lien, et des caractères non alphanumériques. Rajoutons volontairement un hashtag ainsi qu'un mot avec accent afin d'avoir un exemple complet avec tous les cas de nettoyage possible.
#
# Le mot <code>that's</code> disparaitraît car il y a un apostrophe (donc considéré comme non alphanumérique). Afin d'éviter ça, on peut transformer les mots contractés sous leur forme décomposée. <code>that's</code> deviendrai <code>that is</code>.

# %%
text_sample = text_sample + " é_è #car."
text_sample
# Out:
# "@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D é_è #car."

# %% [markdown]
# L'objectif serait d'avoir un tel résultat :
#  * <code>awww that is a bummer you shoulda got david carr of third day to do it</code>

# %%
text_sample = contractions.fix(text_sample)
text_sample
# Out:
# '@switchfoot http://twitpic.com/2y1zl - Awww, that is a bummer.  You shoulda got David Carr of Third Day to do it. ;D é_è #car.'

# %% [markdown]
# Afin d'analyser chaque terme, nous pouvons transformer le tweet en liste de termes. Une fois la liste établie, nous pouvons passer au crible chaque terme et réassembler chaque terme pour former un texte nettoyé.
# Nous allons utiliser Spacy pour cette étape.
#
# D'après la doc : https://spacy.io/api/tokenizer, il y a deux méthodes de tokénisations.

# %%
nlp = English()

# Méthode 1
# Création d'un Tokenizer vierge avec uniquement le vocabulaire anglais
tokenizer = Tokenizer(nlp.vocab)
tokens = tokenizer(text_sample)
print(list(tokens))
print()

# Méthode 2
# Création d'un Tokenizer avec les paramètres par défaut pour l'anglais
# y compris les règles de ponctuation et les exceptions
tokenizer = nlp.tokenizer
tokens = tokenizer(text_sample)
print(list(tokens))
print()

# Méthode 3
# Création d'un Tokenizer avec nltk tweet tokenizer
tweet_tokenizer = TweetTokenizer()
print(tweet_tokenizer.tokenize(text_sample))
# Out:
# [@switchfoot, http://twitpic.com/2y1zl, -, Awww,, that, is, a, bummer.,  , You, shoulda, got, David, Carr, of, Third, Day, to, do, it., ;D, é_è, #car.]
#
# [@switchfoot, http://twitpic.com/2y1zl, -, Awww, ,, that, is, a, bummer, .,  , You, shoulda, got, David, Carr, of, Third, Day, to, do, it, ., ;D, é_è, #, car, .]
#
# ['@switchfoot', 'http://twitpic.com/2y1zl', '-', 'Awww', ',', 'that', 'is', 'a', 'bummer', '.', 'You', 'shoulda', 'got', 'David', 'Carr', 'of', 'Third', 'Day', 'to', 'do', 'it', '.', ';D', 'é_è', '#car', '.']

# %% [markdown]
# On voit que pour la première méthode, le hashtag n'a pas été séparé du mot, contrairement à la seconde méthode.
#
# La troisième méthode s'avère être la plus efficace. On a les hashtags et les smiley bien isolés. On a également une liste plus propre sans caractères vides, contrairement aux autres méthodes. C'est une méthode faite spécialement pour les tweets.
#
# Notre choix se portera donc sur la troisième méthode de tokénisation. En revanche, pour avoir une pipeline spacy, il faudra certainement utiliser une méthode de tokenisation de spacy. Le choix se porterait donc sur la deuxième méthode.

# %%
tokenizer = TweetTokenizer()
tokens = tokenizer.tokenize(text_sample)
tokens
# Out:
# ['@switchfoot',
#  'http://twitpic.com/2y1zl',
#  '-',
#  'Awww',
#  ',',
#  'that',
#  'is',
#  'a',
#  'bummer',
#  '.',
#  'You',
#  'shoulda',
#  'got',
#  'David',
#  'Carr',
#  'of',
#  'Third',
#  'Day',
#  'to',
#  'do',
#  'it',
#  '.',
#  ';D',
#  'é_è',
#  '#car',
#  '.']

# %% [markdown]
# **Suppression des mentions, hashtag et liens. Transformation des majuscules en minuscules.**

# %%
for term_to_remove in ["@", "#", "http", "www."]:
    tokens = [token for token in tokens if term_to_remove not in str(token)]
    
# Majuscules en minuscules
tokens = [str(token).lower() for token in tokens]

tokens
# Out:
# ['-',
#  'awww',
#  ',',
#  'that',
#  'is',
#  'a',
#  'bummer',
#  '.',
#  'you',
#  'shoulda',
#  'got',
#  'david',
#  'carr',
#  'of',
#  'third',
#  'day',
#  'to',
#  'do',
#  'it',
#  '.',
#  ';d',
#  'é_è',
#  '.']

# %% [markdown]
# Des espaces vides, mots avec accent et caractères non alphanumériques sont toujours présents.

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# **Suppression des accents et caractères non alphanumériques**

# %%
[token for token in tokens if str(token).isalnum()]
# Out:
# ['awww',
#  'that',
#  'is',
#  'a',
#  'bummer',
#  'you',
#  'shoulda',
#  'got',
#  'david',
#  'carr',
#  'of',
#  'third',
#  'day',
#  'to',
#  'do',
#  'it']

# %% [markdown]
# Nous avons maintenant finaliser l'étape de nettoyage et avons pu conserver l'intégrité du tweet.
# * <code>awww, that is a bummer. you shoulda got david carr of third day to do it.</code>

# %% [markdown]
# ## Automatisation du processus de nettoyage

# %% [markdown]
# Il faut maintenant appliquer tous les processus de nettoyage au jeu de données.

# %%
def clean_tweet(tweet:str):
    # On traite les formes contractées pour ne pas avoir de perte
    # de données.
    tweet = contractions.fix(tweet)
    
    # Tokenisation
    tweet_tokenizer = TweetTokenizer()
    tokenised_tweet = tweet_tokenizer.tokenize(tweet)
    
    # Suppressions des mentions, hashtags et liens
    for term_to_remove in ["@", "#", "http", "www."]:
        tokens = [token for token in tokenised_tweet if term_to_remove not in str(token)]

    # Majuscules en minuscules.
    tokens = [str(token).lower() for token in tokens]
    
    # Suppression des accents et caractères spéciaux.
    tokens = [token for token in tokens if str(token).isalnum()]
    
    return ' '.join(tokens)

# %% [markdown]
# Testons maintenant la fonction.

# %%
text_sample = twitter_data_sample["text"].iloc[0]
text_sample
# Out:
# "@switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D"

# %%
clean_tweet(text_sample)
# Out:
# 'awww that is a bummer you shoulda got david carr of third day to do it'

# %% [markdown]
# La fonction a l'air de bien fonctionner. On peut maintenant l'appliquer dans tout le jeu de données

# %%
# On applique la fonction clean_tweet dans nos données
twitter_data_sample["cleaned_text"] = twitter_data_sample.text.apply(
    lambda tweet: clean_tweet(tweet))

# On affiche les cinq premières lignes de données (pour vérifier à nouveau)
twitter_data_sample.head()
# Out:
#    target                                               text  \
# 0       0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1       0  is upset that he can't update his Facebook by ...
# 2       0  @Kenichan I dived many times for the ball. Man...
# 3       0    my whole body feels itchy and like its on fire
# 4       0  @nationwideclass no, it's not behaving at all....
#
#                                         cleaned_text
# 0  awww that is a bummer you shoulda got david ca...
# 1  is upset that he cannot update his facebook by...
# 2  i dived many times for the ball managed to sav...
# 3     my whole body feels itchy and like its on fire
# 4  no it is not behaving at all i am mad why am i...

# %%
twitter_data_sample.to_csv("tweet_dataset.csv", index=False)

# %%
twitter_validation_set["cleaned_text"] = twitter_validation_set.text.apply(
    lambda tweet: clean_tweet(tweet))

twitter_validation_set.head()
# Out:
#        target                                               text  \
# 10025       0  @Violet_Crush Sorry to hear that  But at least...
# 10026       0                   I broke the vibrate on my fone.
# 10027       0  Race was good! Ran better than last time. Didn...
# 10028       0  @IngaLeonora I just got home but really didn't...
# 10029       0                                   @emkins i KNOW!
#
#                                             cleaned_text
# 10025  sorry to hear that but at least you are with u...
# 10026                     i broke the vibrate on my fone
# 10027  race was good ran better than last time did no...
# 10028  i just got home but really did not want to was...
# 10029                                             i know

# %%
twitter_validation_set.to_csv("validation_set.csv")

# %% [markdown]
# En général, un mot a plusieurs significations en fonction de son utilisation dans le texte. De même, différentes formes de mots véhiculent des significations connexes, comme "jouet" et "jouets", qui indiquent une signification identique.
#
# On ne trouvera probablement pas d'objectifs différents entre une recherche de "jouet" et une recherche de "jouets". Ce type de contraste entre différentes formes de mots est appelé "inflexion", mais il pose divers problèmes de compréhension pour la machine.
#
# Pour rendre cela plus compréhensible par la machine, on utilsera deux méthodes différentes :
# * La lemmatisation
# * Le stemming

# %% [markdown]
# ## Lemmatisation
# **Qu'est ce que la lemmatisation ?**
#
# D'une manière générale, une méthode qui fait passer n'importe quelle forme d'un mot à son mode de racine de base est appelée "lemmatisation".
#
# En d'autres termes, la lemmatisation est une méthode responsable du regroupement de différentes formes infléchies de mots dans la forme racine, ayant la même signification. Elle est similaire au stemming, mais elle permet d'obtenir un mot dépouillé ayant une certaine signification dans un dictionnaire. L'analyse morphologique nécessite l'extraction du lemme correct de chaque mot.
#
# Par exemple, la lemmatisation identifie clairement la forme de base de "troubled" en "trouble", ce qui dénote un certain sens, tandis que la radicalisation élimine la partie "ed" et la convertit en "troubl".
#
# "Troubled" -> Lemmatisation -> "Troubl".

# %%
nlp = spacy.load('en_core_web_sm')

def lemmatizer(text):
    sent = []
    doc = nlp(text)
    for word in doc:
        sent.append(word.lemma_)
    return " ".join(sent)

# %%
# Avant lemmatisation
clean_tweet(text_sample)
# Out:
# 'awww that is a bummer you shoulda got david carr of third day to do it'

# %%
# Après lemmatisation
lemmatizer(clean_tweet(text_sample))
# Out:
# 'awww that be a bummer you shoulda get david carr of third day to do it'

# %%
# On applique la fonction lemmatizer dans une nouvelle colonne
twitter_data_sample["lemmatized_text"] = twitter_data_sample["cleaned_text"].apply(
    lambda tweet: lemmatizer(tweet))

# %%
twitter_data_sample
# Out:
#         target                                               text  \
# 0            0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1            0  is upset that he can't update his Facebook by ...
# 2            0  @Kenichan I dived many times for the ball. Man...
# 3            0    my whole body feels itchy and like its on fire
# 4            0  @nationwideclass no, it's not behaving at all....
# ...        ...                                                ...
# 804003       4  after smoking for 16 years , i have now not ha...
# 804004       4                 @libbyoliver Hes my Ravin Rabbid!
# 804005       4  And I'm quite chuffed: Finally shelled out the...
# 804006       4  u would never think that three 15 year olds wh...
# 804007       4  back to the grind of a 9-5, only for three day...
#
#                                              cleaned_text  \
# 0       awww that is a bummer you shoulda got david ca...
# ...

# %% [markdown]
# ## Stemming
#
# **Qu'est-ce que le stemming ?**
#
# Nous savons déjà qu'un mot a une forme racine-base mais qu'il peut avoir différentes variations. Par exemple, "play" est un mot racine et "played", "playing", "plays" sont les différentes formes fléchies.
#
# Le processus de réduction de l'inflexion vers leur forme racine est appelé "stemming", ce qui permet de représenter un groupe de mots apparentés sous la même racine, même si celle-ci n'a pas de sens approprié.
#
# Spacy ne possède pas de fonction de stemming, on utilisera donc nltk.

# %%
stemmer = SnowballStemmer("english")

# %%
for word in ["played", "playing", "plays"]:
    print(stemmer.stem(word))
# Out:
# play
# play
# play

# %%
twitter_data_sample['stemmed_text'] = twitter_data_sample['cleaned_text'].str.split()
twitter_data_sample['stemmed_text'] = twitter_data_sample['stemmed_text'].apply(
    lambda tweet: [stemmer.stem(word) for word in tweet])
twitter_data_sample['stemmed_text'] = twitter_data_sample['stemmed_text'].apply(
    lambda tweet: " ".join(tweet))

# %%
twitter_data_sample
# Out:
#         target                                               text  \
# 0            0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1            0  is upset that he can't update his Facebook by ...
# 2            0  @Kenichan I dived many times for the ball. Man...
# 3            0    my whole body feels itchy and like its on fire
# 4            0  @nationwideclass no, it's not behaving at all....
# ...        ...                                                ...
# 804003       4  after smoking for 16 years , i have now not ha...
# 804004       4                 @libbyoliver Hes my Ravin Rabbid!
# 804005       4  And I'm quite chuffed: Finally shelled out the...
# 804006       4  u would never think that three 15 year olds wh...
# 804007       4  back to the grind of a 9-5, only for three day...
#
#                                              cleaned_text  \
# 0       awww that is a bummer you shoulda got david ca...
# ...

# %% [markdown]
# ## Encoding
#
# Comme les étiquettes de chaque tweet dans le jeu de données sont annotées comme 0 pour négatif et 4 pour positif, un encodeur d'étiquettes (label encoder) est utilisé pour transformer les étiquettes en 0 pour négatif et 1 pour positif. Afin de conserver un modèle de classification binaire commun.

# %%
# Création d'un label encoder
encoder = LabelEncoder()

# Encodage des étiquettes (0 ou 1) dans les données d'entraînement
encoder.fit(twitter_data_sample.target.to_list())
twitter_data_sample.target = encoder.transform(
    twitter_data_sample.target.to_list())

twitter_data_sample
# Out:
#         target                                               text  \
# 0            0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1            0  is upset that he can't update his Facebook by ...
# 2            0  @Kenichan I dived many times for the ball. Man...
# 3            0    my whole body feels itchy and like its on fire
# 4            0  @nationwideclass no, it's not behaving at all....
# ...        ...                                                ...
# 804003       1  after smoking for 16 years , i have now not ha...
# 804004       1                 @libbyoliver Hes my Ravin Rabbid!
# 804005       1  And I'm quite chuffed: Finally shelled out the...
# 804006       1  u would never think that three 15 year olds wh...
# 804007       1  back to the grind of a 9-5, only for three day...
#
#                                              cleaned_text  \
# 0       awww that is a bummer you shoulda got david ca...
# ...

# %% [markdown]
# # Séparation du jeu de données
# La division des données est fixée à 80 % pour l'ensemble de données d'apprentissage et à 20 % pour l'ensemble de données de test. Comme les fonctions train_test_split rendent les données aléatoires, le paramètre stratify est défini de manière à avoir la même quantité de classes positives et négatives dans chaque ensemble de données.

# %%
# 80% pour nos données à entraîner
train_size = 0.8

# diviser nos données en un ensemble d'entraînement (80%)
# et un ensemble de test (20%).
train_data, test_data = train_test_split(twitter_data_sample[["target", "cleaned_text"]],
                                         test_size=1 - train_size,
                                         random_state=0,
                                         stratify=twitter_data_sample.target)
train_data.to_csv("train_dataset.csv")
test_data.to_csv("test_dataset.csv")

# Idem pour données lemmatisé
train_data_lem, test_data_lem = train_test_split(twitter_data_sample[["target", "lemmatized_text"]],
                                                 test_size=1 - train_size,
                                                 random_state=0,
                                                 stratify=twitter_data_sample.target)

# Idem pour données stem
train_data_stem, test_data_stem = train_test_split(twitter_data_sample[["target", "stemmed_text"]],
                                                   test_size=1 - train_size,
                                                   random_state=0,
                                                   stratify=twitter_data_sample.target)

print("="*50)
# la longueur de chaque ensemble
print("Taille des données d'entraînement                    : ", len(train_data))
print("Taille des données de test                           : ", len(test_data))

print("="*50)
print("Taille des données d'entraînement avec lemmatization : ",
      len(train_data_lem))
print("Taille des données de test avec lemmatization        : ",
      len(test_data_lem))

print("="*50)
print("Taille des données d'entraînement avec stemming      : ",
      len(train_data_stem))
print("Taille des données de test avec stemming             : ",
      len(test_data_stem))

print("="*50)
# Combien d'exemples de chaque classe il y a dans chaque ensemble.
print("Distribution des données d'entraînement :\n",
      pd.DataFrame(train_data.target.value_counts()))
print()
print("Distribution des données de test :\n",
      pd.DataFrame(test_data.target.value_counts()))

print("="*50)
print("Distribution des données d'entraînement avec lemmatization :\n",
      pd.DataFrame(train_data_lem.target.value_counts()))
print()
print("Distribution des données de test avec lemmatization :\n",
      pd.DataFrame(test_data_lem.target.value_counts()))

print("="*50)
print("Distribution des données d'entraînement avec stemming :\n",
      pd.DataFrame(train_data_stem.target.value_counts()))
print()
print("Distribution des données de test avec stemming :\n",
      pd.DataFrame(test_data_stem.target.value_counts()))
# Out:
# ...
# Taille des données d'entraînement                    :  6400
# Taille des données de test                           :  1600
# ...
# Taille des données d'entraînement avec lemmatization :  6400
# Taille des données de test avec lemmatization        :  1600
# ...
# Taille des données d'entraînement avec stemming      :  6400
# Taille des données de test avec stemming             :  1600
# ...
# Distribution des données d'entraînement :
#     target
# 1    3200
# 0    3200
#
# Distribution des données de test :
#     target
# 0     800
# 1     800
# ...
# Distribution des données d'entraînement avec lemmatization :
#     target
# 1    3200
# 0    3200
#
# Distribution des données de test avec lemmatization :
#     target
# 0     800
# 1     800
# ...
# Distribution des données d'entraînement avec stemming :
#     target
# 1    3200
# 0    3200
#
# Distribution des données de test avec stemming :
#     target
# 0     800
# 1     800

# %%
twitter_data_sample[~twitter_data_sample.index.isin(train_data.index)]
# Out:
#         target                                               text  \
# 0            0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 3            0    my whole body feels itchy and like its on fire
# 7            0  @LOLTrish hey  long time no see! Yes.. Rains a...
# 21           0  one of my friend called me, and asked to meet ...
# 24           0                         blagh class at 8 tomorrow
# ...        ...                                                ...
# 803983       1  Nearly a full house at #theBarn today. Nice at...
# 803998       1                         today's gonna be gooooood
# 804001       1  @LichfieldBlog You're forgiven. There's a foot...
# 804002       1  @unitej wow congratulations!!! That's awesome!...
# 804005       1  And I'm quite chuffed: Finally shelled out the...
#
#                                              cleaned_text  \
# 0       awww that is a bummer you shoulda got david ca...
# ...

# %%
# transformer les étiquettes des données y_train et y_test en étiquettes encodées
y_train = train_data.target
y_test = test_data.target

y_train.to_csv("y_train.csv")
y_test.to_csv("y_test.csv")

y_train_lem = train_data_lem.target
y_test_lem = test_data_lem.target

y_train_stem = train_data_stem.target
y_test_stem = test_data_stem.target

# remodeler les données y_train et y_test
y_train = np.array(y_train).reshape(-1, 1)
y_test = np.array(y_test).reshape(-1, 1)

y_train_lem = np.array(y_train_lem).reshape(-1, 1)
y_test_lem = np.array(y_test_lem).reshape(-1, 1)

y_train_stem = np.array(y_train_stem).reshape(-1, 1)
y_test_stem = np.array(y_test_stem).reshape(-1, 1)

# %% [markdown]
# # Tokenization
#
# À ce stade, les tweets sont encore des phrases normales. Le processus de tokenisation transforme une séquence de caractères en tokens. Cela signifie qu'il faut "découper" les phrases en morceaux, convertir chaque mot en un index et éliminer les caractères de ponctuation.

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

# %%
# créer un tokeniseur
tokenizer = Tokenizer()
tokenizer_lem = Tokenizer()
tokenizer_stem = Tokenizer()

# ajuster le tokeniseur dans le texte d'entraînement
tokenizer.fit_on_texts(train_data.cleaned_text)
tokenizer_lem.fit_on_texts(train_data_lem.lemmatized_text)
tokenizer_stem.fit_on_texts(train_data_stem.stemmed_text)

# %%
# Sauvegarde du tokeniseur.
with open('data/clean/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# Les phrases sont maintenants transformées.
#
# Toutefois, elles ne sont pas encore prêtes pour entraîner un réseau neuronal à analyser les sentiments exprimés dans le texte. Quand on entraîne un réseau neuronal avec une collection de tenseurs, tous les tenseurs doivent avoir la même longueur. Or les listes représentant les tweets dans x_train et x_test (cellule ci-dessous) sont de longueur différente.
#
# Heureusement, Keras inclut une fonction qui prend une liste de listes en entrée et convertit les listes internes à une longueur spécifiée, en les tronquant si nécessaire ou en les remplissant avec des zéros (0).

# %%
# obtenir la longueur maximale des données du train
max_length = max([len(s.split()) for s in train_data.cleaned_text])
max_length_lem = max([len(s.split()) for s in train_data_lem.lemmatized_text])
max_length_stem = max([len(s.split()) for s in train_data_stem.stemmed_text])

# rembourrer les séquences dans l'ensemble de données x_train à la longueur maximale
x_train = pad_sequences(tokenizer.texts_to_sequences(train_data.cleaned_text),
                        maxlen=max_length)

x_train_lem = pad_sequences(tokenizer_lem.texts_to_sequences(
    train_data_lem.lemmatized_text), maxlen=max_length_lem)

x_train_stem = pad_sequences(tokenizer_stem.texts_to_sequences(
    train_data_stem.stemmed_text), maxlen=max_length_stem)

# rembourrer les séquences dans l'ensemble de données x_test à la longueur maximale
x_test = pad_sequences(tokenizer.texts_to_sequences(test_data.cleaned_text),
                       maxlen=max_length)

x_test_lem = pad_sequences(tokenizer_lem.texts_to_sequences(
    test_data_lem.lemmatized_text), maxlen=max_length_lem)

x_test_stem = pad_sequences(tokenizer_stem.texts_to_sequences(
    test_data_stem.stemmed_text), maxlen=max_length_stem)

# %%
pd.DataFrame(x_train).to_csv("X_train.csv")
pd.DataFrame(x_test).to_csv("X_test.csv")

# %%
print("Dimension du x_train : ", x_train.shape)
print("Dimension du x_test : ", x_test.shape)

print("Dimension du y_train shape : ", y_train.shape)
print("Dimension du y_test shape : ", y_test.shape)

print("Dimension du x_train avec lemmatisation : ", x_train_lem.shape)
print("Dimension du x_test avec lemmatisation : ", x_test_lem.shape)

print("Dimension du y_train shape avec lemmatisation : ", y_train_lem.shape)
print("Dimension du y_test shape avec lemmatisation : ", y_test_lem.shape)

print("Dimension du x_train avec stemming : ", x_train_stem.shape)
print("Dimension du x_test avec stemming : ", x_test_stem.shape)

print("Dimension du y_train shape avec stemming : ", y_train_stem.shape)
print("Dimension du y_test shape avec stemming : ", y_test_stem.shape)
# Out:
# Dimension du x_train :  (6400, 54)
# Dimension du x_test :  (1600, 54)
# Dimension du y_train shape :  (6400, 1)
# Dimension du y_test shape :  (1600, 1)
# Dimension du x_train avec lemmatisation :  (6400, 54)
# Dimension du x_test avec lemmatisation :  (1600, 54)
# Dimension du y_train shape avec lemmatisation :  (6400, 1)
# Dimension du y_test shape avec lemmatisation :  (1600, 1)
# Dimension du x_train avec stemming :  (6400, 54)
# Dimension du x_test avec stemming :  (1600, 54)
# Dimension du y_train shape avec stemming :  (6400, 1)
# Dimension du y_test shape avec stemming :  (1600, 1)

# %% [markdown]
# Les dimensions de x_train et de x_test sont bien de même longueur.

# %% [markdown]
# Passons maintenant au **Prolongement de mot (Word Embedding en anglais) :**
#
# cette technique permet de représenter chaque mot d'un dictionnaire par un vecteur. Par exemple, on pourrait s'attendre à ce que les mots "chien" et "chat" soient représentés par des vecteurs relativement peu distants dans l'espace vectoriel.
#
# La technique des plongements lexicaux diminue la dimension de la représentation des mots et facilite ainsi les tâches d'apprentissage impliquant ces mots. Cette technique permet de capturer le contexte et la sémantique d'un mot en relation avec d'autres mots.
#
# Nous essayerons deux algorithmes de prolongement de mot :
# * Glove
# * FastText
#
# Les deux algorithmes, FastText et Glove, nous permettent de représenter un mot sous la forme d'un vecteur. Il s'agit des deux algorithmes les plus populaires pour le prolongement de mots.
#
# **Quelle est la différence entre les deux modèles ? :** Pour faire court, Les algorithmes FastText sont basés sur l'entraînement d'un réseau de neurones à propagation avant, tandis que les algorithmes de Glove se basent sur des techniques de factorisation de matrices.
#
# * Avec FastText, le modèle tente de capturer la cooccurrence une fenêtre à la fois.
# * Avec Glove, on essaie de récupérer le décompte des statistiques globales en fonction de leur fréquence d'apparition.
#
# Voici à quoi ressemble visuellement un prolongement de mot : https://projector.tensorflow.org/.

# %% [markdown]
# # Glove
#
# Pour utiliser Glove, on a besoin de charger un fichier téléchargeable via le lien suivant :
# https://nlp.stanford.edu/projects/glove/
#
# https://machinelearningmastery.com/develop-word-embedding-model-predicting-movie-review-sentiment/

# %%
# load embedding as a dict
def load_embedding(filename):
    # load embedding into memory, skip first line
    file = open(filename, 'r', encoding="utf-8")
    lines = file.readlines()
    file.close()

    # create a map of words to vectors
    embedding = dict()
    for line in lines:
        parts = line.split()
        # key is string word, value is numpy array for vector
        embedding[parts[0]] = asarray(parts[1:], dtype='float32')
    return embedding


# create a weight matrix for the Embedding layer from a loaded embedding
def get_weight_matrix(embedding, vocab):
    # total vocabulary size plus 0 for unknown words
    vocab_size = len(vocab) + 1

    # define weight matrix dimensions with all 0
    weight_matrix = zeros((vocab_size, embedding_dim))

    # step vocab, store vectors using the Tokenizer's integer mapping
    for word, i in vocab.items():
        vector = embedding.get(word)
        if vector is not None:
            weight_matrix[i] = vector
    return weight_matrix

# %%
# contient l'index de chaque mot
vocab = tokenizer.word_index

# le nombre total de mots de notre vocabulaire, plus un pour les mots inconnus
vocab_size = len(tokenizer.word_index) + 1

# dimensions du plongement
embedding_dim = 200

print("Taille du vocabulaire : ", vocab_size)
print("Longueur maximale : ", max_length)

# charger le plongement depuis le fichier
raw_embedding = load_embedding('glove.twitter.27B.200d.txt')

# obtenir les vecteurs dans le bon ordre
embedding_matrix = get_weight_matrix(raw_embedding, vocab)
# Out:
# Taille du vocabulaire :  9887
# Longueur maximale :  54

# %% [markdown]
# La couche d'incorporation transforme les séquences d'entrée en vecteurs denses. Pour configurer cette couche, la taille du vocabulaire a été fixée à 9887, la dimension d'intégration à 200 (car les 200d vecteurs de GloVe ont été utilisés) et la longueur d'entrée à 54.

# %%
# créer la couche de plongement
glove_embedding_layer = Embedding(vocab_size,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %% [markdown]
# # FastText

# %% [markdown]
# https://radimrehurek.com/gensim/models/fasttext.html

# %%
def fast_text(X,
              FT_SIZE=200,
              FT_WINDOW=7,FT_EPOCH=32,
              FT_MIN_COUNT=10,
              SEQUENCE_LENGTH=54,
              workers=32):
    """
    Paramètres d'entrainement :
        - FT_SIZE : Le nombre de dimensions (N) sur lesquelles FastText fait
            correspondre les mots. Des valeurs de taille plus grandes nécessitent
            plus de données d'entraînement, mais peuvent conduire à de meilleurs
            modèles (plus précis).

        - FT_WINDOW : La distance maximale entre un mot cible et les mots autour
            du mot cible.

        - FT_EPOCH : Le nombre d'"epoch" est un hyperparamètre qui définit le
            nombre de fois que l'algorithme d'apprentissage travaillera sur
            l'ensemble des données d'apprentissage. Une "epoch" signifie que
            chaque échantillon de l'ensemble de données d'apprentissage a eu
            l'occasion de mettre à jour les paramètres du modèle interne.

        - FT_MIN_COUNT : min_count sert à élaguer le dictionnaire interne.
            Les motsqui n'apparaissent qu'une ou deux fois dans un corpus d'un
            milliard de mots sont probablement des fautes de frappe et des
            déchets inintéressants. De plus, il n'y a pas assez de données
            pour effectuer un apprentissage significatif sur ces mots, il est
            donc préférable de les ignorer.

        - SEQUENCE_LENGTH : Définit la taille du vocabulaire et le nombre de
            mots d'une séquence. Pour rappel, la tokénisation a été paramétrée
            sur une longueur de 54. On fixe donc ce paramètre sur 54.

        - workers : Spécifie le nombre de fils de travail pour la parallélisation
            de l'entrainement, afin d'accélérer l'entrainement.
    """

    documents = [_text.split() for _text in X]
    ft_model = gensim.models.fasttext.FastText(vector_size=FT_SIZE,
                                                window=FT_WINDOW,
                                                min_count=FT_MIN_COUNT,
                                                workers=workers)
    ft_model.build_vocab(documents)

    ft_model.train(documents, total_examples=len(documents), epochs=FT_EPOCH)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(X)

    vocab_size = len(tokenizer.word_index) + 1
    embedding_matrix = np.zeros((vocab_size, FT_SIZE))
    for word, i in tokenizer.word_index.items():
        if word in ft_model.wv.index_to_key:
            embedding_matrix[i] = ft_model.wv.get_vector(word, norm=True)

    embedding_layer_fast_text = Embedding(vocab_size,
                                           FT_SIZE,
                                           weights=[embedding_matrix],
                                           input_length=SEQUENCE_LENGTH,
                                           trainable=False)

    return embedding_layer_fast_text

# %%
x_train_ft = train_data["cleaned_text"].values
ft_embedding_layer = fast_text(x_train_ft)

x_train_ft_lem = train_data_lem["lemmatized_text"].values
ft_embedding_layer_lem = fast_text(x_train_ft_lem)

x_train_ft_stem = train_data_stem["stemmed_text"].values
ft_embedding_layer_stem = fast_text(x_train_ft_stem)

# %% [markdown]
# # Fonctions utiles

# %%
def plot_confusion_matrix(model, x_test, y_test, model_title='Modèle'):
    y_pred = (model.predict(x_test).ravel() > 0.5) + 0
    classes = ['negative', 'positive']
    model_title = 'Matrice de confusion - ' + model_title
    cm = confusion_matrix(y_test, y_pred)
    cr = classification_report(y_test, y_pred)

    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    plt.text(-0.3, -0.7, model_title, fontweight='bold')

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j,
                 i,
                 cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('Réelle')
    plt.xlabel('Estimée')
    plt.show()
    print(cr)

# %%
def plot_model(history_model):
    # graphique des performances du modèle
    acc = history_model.history['acc']
    val_acc = history_model.history['val_acc']
    loss = history_model.history['loss']
    val_loss = history_model.history['val_loss']
    auc = history_model.history['auc']
    val_auc = history_model.history['val_auc']

    epochs = range(1, len(acc) + 1)

    plt.plot(epochs, acc, 'bo', label="Accuracy de l'entraînement")
    plt.plot(epochs, val_acc, 'b', label="Accuracy de la validation")
    plt.title("Accuracy de l'entraînement et de la validation")
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, 'bo', label="Perte à l'entraînement")
    plt.plot(epochs, val_loss, 'b', label="Perte à la validation")
    plt.title("Perte à l'entraînement et à la validation")
    plt.legend()
    plt.show()

    plt.plot(epochs, auc, 'bo', label="AUC à l'entraînement")
    plt.plot(epochs, val_auc, 'b', label="AUC à la validation")
    plt.title("AUC à l'entraînement et à la validation")
    plt.legend()
    plt.show()

# %% [markdown]
# # Baseline SimpleRNN avec Glove
#
# https://docs.microsoft.com/fr-fr/learn/modules/analyze-review-sentiment-with-keras/2-build-and-train-a-neural-network
#
# **Qu'est-ce qu'un réseau de neurone RNN ?**
#
# Les réseaux de neurones récurrents (RNN) sont une classe de réseaux de neurones puissants pour modéliser des données de séquence telles que les séries chronologiques ou le langage naturel.
#
# Schématiquement, une couche RNN utilise une boucle <code>for</code> pour itérer sur les pas de temps d'une séquence, tout en maintenant un état interne qui code pour des informations sur les pas de temps qu'il a vu jusqu'à présent.
#
# Une connexion récurrente permet de réinjecter la sortie d'une couche en entrée de celle-ci. Comme toutes les autres connexions, on lui attribue un poids qui sera réglé lors de la phase d'apprentissage.
#
# Des connexions récurrentes permettent au réseau de neurones à un instant  t de "voir" la fenêtre correspondante à cet instant, mais aussi de se "souvenir" de sa décision à un instant précédent.
#
# ##### Initialisation du modèle
# Le code qui suit est la base à partir duquel on construira un réseau neuronal de base avec Keras. Il instancie d’abord un objet **Sequential** représentant un modèle « séquentiel », qui se compose d’une pile de couches de bout en bout où la sortie d’une couche constitue l’entrée de la couche suivante.
#
# Les lignes de code suivantes, avec la méthode <code>.add</code>, ajoutent des couches au modèle.
#
# ##### Couche d’incorporation
# **La première est une couche d’incorporation**, qui est essentielle dans les réseaux neuronaux qui traitent des mots. La couche d’incorporation (ou prolongement de mots) mappe essentiellement des tableaux à plusieurs dimensions contenant des index de mots entiers en tableaux de valeurs à virgule flottante contenant moins de dimensions. Elle permet également de traiter des mots ayant des significations similaires de manière identique. C'est ce qui a été expliqué précédement à la fin de la partie 7.
#
# ##### Couche de régularisation SpatialDropout1D
# https://keras.io/api/layers/regularization_layers/spatial_dropout1d/
#
# Après l’ajout de la couche d’incorporation, **SpatialDropout1D** est appelé. Le dropout est l'une des techniques de régularisation les plus efficaces et les plus couramment utilisées pour les NNs. Il consiste à désactiver de manière aléatoire les unités cachées pendant l'entraînement, de sorte que le réseau ne se fie pas à 100 % à tous ses neurones et se force à trouver des modèles plus significatifs dans les données afin d'augmenter la métrique qu'on essaye d'optimiser.
#
# Cette version (SpatialDropout1D) exécute la même fonction que Dropout, cependant, elle laisse tomber les dimensions de caractéristique 1D entières au lieu d'éléments individuels. Si les images adjacentes dans les dimensions de caractéristiques sont fortement corrélées (comme c'est normalement le cas dans les premières couches de convolution), le dropout régulier ne régularisera pas les activations et ne fera que diminuer le taux d'apprentissage effectif. Dans ce cas, SpatialDropout1D aidera à promouvoir l'indépendance entre les dimensions de caractéristiques et devrait être utilisé à la place.
#
# ##### Couche SimpleRNN
# https://www.tensorflow.org/guide/keras/rnn
#
# C'est une couche **RNN** entièrement connecté, où le signal de sortie timestep précédente doit être alimentée au prochain pas de temps.
#
# Par défaut, la sortie d'une couche RNN contient un seul vecteur par échantillon. Ce vecteur est la sortie de la cellule RNN correspondant au dernier pas de temps, contenant des informations sur l'ensemble de la séquence d'entrée. La forme de cette sortie est (batch_size, units) où des units correspond à l' units argument passé au constructeur de la couche.
#
# ##### Couche de régularisation Dropout
# https://keras.io/api/layers/regularization_layers/dropout/
#
# La couche **Dropout** définit aléatoirement les unités d'entrée de 0 à 1 à chaque étape de la période d'entraînement, ce qui permet d'éviter le sur-entraînement.
#
# ##### Fonction d'activation
# Une fonction d'activation dans un réseau neuronal définit comment la somme pondérée de l'entrée est transformée en une sortie à partir d'un ou plusieurs nœuds dans une couche du réseau.
#
# Le choix de la fonction d'activation a un impact important sur la capacité et les performances du réseau neuronal, et différentes fonctions d'activation peuvent être utilisées dans différentes parties du modèle.
#
# ##### Couche Dense
# https://keras.io/api/layers/core_layers/dense/
#
# Les deux couches ajoutées au modèle sont des **couches denses**, également appelées couches entièrement connectées. Ce sont les couches classiques qui figurent en principe dans les réseaux neuronaux. Chaque couche contient <code>n</code> nœuds ou neurones, et chaque neurone reçoit une entrée de chaque neurone de la couche précédente, d’où le terme de couches « entièrement connectées ».
#
# Ces couches permettent au réseau neuronal d’« apprendre » à partir des données d’entrée en devinant la sortie de manière itérative, en vérifiant les résultats et en ajustant les connexions pour affiner les résultats. La première couche dense dans ce réseau contient 64 neurones. Ce nombre a été choisi arbitrairement. On peut essayer différentes tailles afin d’améliorer la précision du modèle. La dernière couche dense contient un seul neurone, car l’objectif final du réseau est de **prédire** une sortie unique, à savoir un **score de sentiment** compris entre **0.0** et **1.0**.
#
# https://machinelearningmastery.com/choose-an-activation-function-for-deep-learning/.

# %%
model_baseline_glv = Sequential(name='baseline_glove')
# layer 1
model_baseline_glv.add(glove_embedding_layer)
model_baseline_glv.add(SpatialDropout1D(0.5))
model_baseline_glv.add(SimpleRNN(128, dropout=0.5))
model_baseline_glv.add(Dropout(0.5))

# layer 2
model_baseline_glv.add(
    Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model_baseline_glv.add(Dropout(0.5))

# Output Layer
model_baseline_glv.add(Dense(1, activation='sigmoid'))

model_baseline_glv.summary()
# Out:
# Model: "baseline_glove"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 54, 200)           1977400
#
#  spatial_dropout1d (SpatialD  (None, 54, 200)          0
#  ropout1D)
#
#  simple_rnn (SimpleRNN)      (None, 128)               42112
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# ...
# Total params: 2,027,833
# Trainable params: 50,433
# Non-trainable params: 1,977,400
# _________________________________________________________________

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, min_lr=0.01)

# %%
dir_log = os.path.join('logs', datetime.now().strftime("%Y%m%d-%H%M%S"))
callback_tensorboard = tf.keras.callbacks.TensorBoard(dir_log, histogram_freq=1)

# %% [markdown]
# ## Baseline : SimpleRNN + Glove

# %%
# Compiler le modèle
model_baseline_glv.compile(
    loss='binary_crossentropy',
    optimizer="adam",
    metrics=['acc', 'AUC',
             tf.keras.metrics.FalsePositives(name='fp')])

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_baseline_glv = model_baseline_glv.fit(x_train,
                                              y_train,
                                              epochs=20,
                                              batch_size=1024,
                                              validation_split=0.1,
                                              verbose=0,
                                              callbacks=[reduce_lr,
                                                         callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_baseline_glv.save('data/clean/simplernn_glove.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
# Évaluation
evaluation_baseline = model_baseline_glv.evaluate(x_test, y_test, batch_size=1024)
print('Test Accuracy: %f' % (evaluation_baseline[1]*100))
# Out:
# 2/2 [==============================] - 0s 56ms/step - loss: 0.7446 - acc: 0.6006 - auc: 0.6544 - fp: 147.0000
# Test Accuracy: 60.062498

# %% [markdown]
# ### Visualisation de l'apprentissage
# https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/
#
# * Les courbes d'apprentissage sont des graphiques qui montrent l'évolution des performances d'apprentissage au fil du temps.
#
#
# * Les courbes d'apprentissage de la performance du modèle sur les ensembles de données d'entraînement et de validation peuvent être utilisées pour diagnostiquer un modèle sous-entraîné, sur-entraîné ou bien entraîné.
#
#
# * Les courbes d'apprentissage de la performance du modèle peuvent être utilisées pour diagnostiquer si les ensembles de données d'entraînement ou de validation sont assez représentatifs du domaine du problème.
#
# On a en abscisse le nombre d'itérations (paramètre <code>epoch</code>) et en ordonné le score (de 0 à 1).
#
# ##### Comment interpreter la visualisation de l'apprentissage ?
# La courbe d'apprentissage montre un **sous-entraînement** si :
# * La courbe de la perte d'apprentissage reste plate quelle que soit la formation.
# * La courbe de la perte d'apprentissage continue de diminuer jusqu'à la fin de l'apprentissage.
#
# La courbe d'apprentissage montre un **sur-entraînement** si :
#
# * La courbe de la perte d'apprentissage continue de diminuer avec l'expérience.
# * La courbe de la perte de validation diminue jusqu'à un certain point et recommence à augmenter.
#
# Un tracé de courbes d'apprentissage montre un **bon entraînement** si :
#
# * La courbe de la perte d'apprentissage diminue jusqu'à un point de stabilité.
# * La courbe de la perte de validation diminue jusqu'à un point de stabilité et présente un faible écart avec la perte de l'entraînement.

# %%
plot_model(history_baseline_glv)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_baseline_glv, x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.82      0.67       800
#            1       0.68      0.39      0.49       800
#
#     accuracy                           0.60      1600
#    macro avg       0.62      0.60      0.58      1600
# weighted avg       0.62      0.60      0.58      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Sauvegarde des résultats
model_results = []

# Dictionnaire
model_results.append({
    'Modèle':
    'SimpleRNN + GloVe',
    'Faux positifs':
    '{:0.0f}'.format(evaluation_baseline[3]),
    'Score ROC (%)':
    '{:0.2f}'.format(evaluation_baseline[2] * 100),
    'Accuracy (%)':
    '{:0.2f}'.format(evaluation_baseline[1] * 100),
    'Perte (%)':
    '{:0.2f}'.format(evaluation_baseline[0] * 100),
    "Temps d'entrainement (s)":
    "{:0.1f}".format(fit_time)
})

# Enregistrement
model_history = pd.DataFrame.from_records(model_results)
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#               Modèle Faux positifs Score ROC (%) Accuracy (%) Perte (%)  \
# 0  SimpleRNN + GloVe           147         65.44        60.06     74.46
#
#   Temps d'entrainement (s)
# 0                     29.8

# %% [markdown]
# ## Baseline SimpleRNN + Glove + Lemma

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_baseline_glv = model_baseline_glv.fit(x_train_lem,
                                              y_train_lem,
                                              epochs=20,
                                              batch_size=1024,
                                              validation_split=0.1,
                                              verbose=0,
                                              callbacks=[reduce_lr, callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_baseline_glv.save('data/clean/simplernn_glove_lemma.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_baseline_lem = model_baseline_glv.evaluate(x_test_lem, y_test_lem, batch_size=1024)
print('Test Accuracy: %f' % (evaluation_baseline_lem[1]*100))
# Out:
# 2/2 [==============================] - 0s 41ms/step - loss: 0.7297 - acc: 0.5000 - auc: 0.5144 - fp: 800.0000
# Test Accuracy: 50.000000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_baseline_glv)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_baseline_glv, x_test_lem, y_test_lem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       800
#            1       0.50      1.00      0.67       800
#
#     accuracy                           0.50      1600
#    macro avg       0.25      0.50      0.33      1600
# weighted avg       0.25      0.50      0.33      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'SimpleRNN + GloVe + Lemma',
        'Faux positifs': '{:0.0f}'.format(evaluation_baseline_lem[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_baseline_lem[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_baseline_lem[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_baseline_lem[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0

# %%
# Sauvegarde des réusltats
model_history.to_csv('data/clean/resultat.csv', index=False)

# %% [markdown]
# ## Baseline : SimpleRNN + Glove + stem

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_baseline_glv = model_baseline_glv.fit(x_train_stem,
                                              y_train_stem,
                                              epochs=20,
                                              batch_size=1024,
                                              validation_split=0.1,
                                              verbose=0,
                                              callbacks=[reduce_lr, callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_baseline_glv.save('data/clean/simplernn_glove_stem.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_baseline_stem = model_baseline_glv.evaluate(x_test_stem, y_test_stem, batch_size=1024)
print('Test Accuracy: %f' % (evaluation_baseline_stem[1]*100))
# Out:
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7167 - acc: 0.5000 - auc: 0.5263 - fp: 800.0000
# Test Accuracy: 50.000000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_baseline_glv)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_baseline_glv, x_test_stem, y_test_stem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       800
#            1       0.50      1.00      0.67       800
#
#     accuracy                           0.50      1600
#    macro avg       0.25      0.50      0.33      1600
# weighted avg       0.25      0.50      0.33      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'SimpleRNN + GloVe + Stem',
        'Faux positifs': '{:0.0f}'.format(evaluation_baseline_stem[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_baseline_stem[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_baseline_stem[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_baseline_stem[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2   SimpleRNN + GloVe + Stem           800         52.63        50.00
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0
# 2     71.67                     29.8

# %% [markdown]
# # Baseline SimpleRNN avec FastText

# %% [markdown]
# ## Baseline : SimpleRNN + FastText

# %% [markdown]
# ### Entrainement du modèle

# %%
model_baseline_ft = Sequential()
# Layer 1
model_baseline_ft.add(ft_embedding_layer)
model_baseline_ft.add(SpatialDropout1D(0.5))
model_baseline_ft.add(SimpleRNN(128, dropout=0.5))
model_baseline_ft.add(Dropout(0.5))

# Layer 2
model_baseline_ft.add(
    Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model_baseline_ft.add(Dropout(0.5))

# Output layer
model_baseline_ft.add(Dense(1, activation='sigmoid'))

model_baseline_ft.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 54, 200)           1977400
#
#  spatial_dropout1d_1 (Spatia  (None, 54, 200)          0
#  lDropout1D)
#
#  simple_rnn_1 (SimpleRNN)    (None, 128)               42112
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 1)                 65
#
# ...
# Total params: 2,027,833
# Trainable params: 50,433
# Non-trainable params: 1,977,400
# _________________________________________________________________

# %% [markdown]
# https://stackoverflow.com/questions/65514944/tensorflow-embeddings-invalidargumenterror-indices18-16-11905-is-not-in-0

# %%
# Compiler le modèle
model_baseline_ft.compile(
    loss='binary_crossentropy',
    optimizer="adam",
    metrics=['acc', 'AUC',
             tf.keras.metrics.FalsePositives(name='fp')])

# Entrainer le modèle
start = time()
history_baseline_ft = model_baseline_ft.fit(x_train,
                                            y_train,
                                            epochs=20,
                                            batch_size=1024,
                                            validation_split=0.1,
                                            verbose=0,
                                            callbacks=[reduce_lr,
                                                       callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_baseline_ft.save('data/clean/simplernn_ft.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_baseline_ft = model_baseline_ft.evaluate(x_test, y_test, batch_size=1024)
# Out:
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6881 - acc: 0.6313 - auc: 0.6907 - fp: 340.0000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_baseline_ft)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_baseline_ft, x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.57      0.61       800
#            1       0.62      0.69      0.65       800
#
#     accuracy                           0.63      1600
#    macro avg       0.63      0.63      0.63      1600
# weighted avg       0.63      0.63      0.63      1600

# %% [markdown]
# ### Sauvegarde des résultat dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'SimpleRNN + FT',
        'Faux positifs': '{:0.0f}'.format(evaluation_baseline_ft[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_baseline_ft[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_baseline_ft[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_baseline_ft[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2   SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3             SimpleRNN + FT           340         69.07        63.13
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0
# 2     71.67                     29.8
# 3     68.81                     27.6

# %% [markdown]
# ## Baseline : SimpleRNN + FastText + Lemma

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_baseline_ft_lem = model_baseline_ft.fit(x_train_lem,
                                                y_train_lem,
                                                epochs=20,
                                                batch_size=1024,
                                                validation_split=0.1,
                                                verbose=0,
                                                callbacks=[reduce_lr,
                                                           callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_baseline_ft.save('data/clean/simplernn_w2v_lem.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_baseline_ft_lem = model_baseline_ft.evaluate(x_test_lem, y_test_lem, batch_size=1024)
# Out:
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7150 - acc: 0.5556 - auc: 0.5670 - fp: 354.0000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_baseline_ft_lem)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_baseline_ft, x_test_lem, y_test_lem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56       800
#            1       0.56      0.55      0.55       800
#
#     accuracy                           0.56      1600
#    macro avg       0.56      0.56      0.56      1600
# weighted avg       0.56      0.56      0.56      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'SimpleRNN + FT + Lemma',
        'Faux positifs': '{:0.0f}'.format(evaluation_baseline_ft_lem[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_baseline_ft_lem[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_baseline_ft_lem[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_baseline_ft_lem[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2   SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3             SimpleRNN + FT           340         69.07        63.13
# 4     SimpleRNN + FT + Lemma           354         56.70        55.56
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0
# 2     71.67                     29.8
# 3     68.81                     27.6
# 4     71.50                     26.3

# %% [markdown]
# ## Baseline : SimpleRNN + FastText + stem

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_baseline_ft_stem = model_baseline_ft.fit(x_train_stem,
                                                 y_train_stem,
                                                 epochs=20,
                                                 batch_size=1024,
                                                 validation_split=0.1,
                                                 verbose=0,
                                                 callbacks=[reduce_lr,
                                                            callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_baseline_ft.save('data/clean/simplernn_ft_stem.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_baseline_ft_stem = model_baseline_ft.evaluate(x_test_stem, y_test_stem, batch_size=1024)
# Out:
# 2/2 [==============================] - 0s 36ms/step - loss: 0.7000 - acc: 0.5519 - auc: 0.5818 - fp: 277.0000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_baseline_ft_stem)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_baseline_ft, x_test_stem, y_test_stem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.65      0.59       800
#            1       0.57      0.45      0.50       800
#
#     accuracy                           0.55      1600
#    macro avg       0.55      0.55      0.55      1600
# weighted avg       0.55      0.55      0.55      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'SimpleRNN + FT + stem',
        'Faux positifs': '{:0.0f}'.format(evaluation_baseline_ft_stem[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_baseline_ft_stem[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_baseline_ft_stem[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_baseline_ft_stem[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2   SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3             SimpleRNN + FT           340         69.07        63.13
# 4     SimpleRNN + FT + Lemma           354         56.70        55.56
# 5      SimpleRNN + FT + stem           277         58.18        55.19
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0
# 2     71.67                     29.8
# 3     68.81                     27.6
# 4     71.50                     26.3
# 5     70.00                     27.1

# %% [markdown]
# # LSTM
# https://keras.io/api/layers/recurrent_layers/lstm/
#
# L'architecture du modèle que nous allons utiliser consiste en un modèle séquentiel avec des couches d'intégration, de suppression, de LSTM et de densité. **La première couche** est la couche d'intégration. Ensuite, une **couche d'exclusion** a été utilisée pour éviter le sur-apprentissage. Le taux pour cette couche a été fixé à 0,2.
#
# La couche suivante est la **couche LSTM**, qui fonctionne avec un mécanisme connu sous le nom d'états cellulaires qui lui permet d'apprendre le contexte des mots en oubliant et en se souvenant sélectivement des choses. La configuration pour cette couche était de 200 unités et un taux d'abandon de 0,2.
#
# Enfin, deux **couches denses** sont ajoutées à la dernière partie du modèle. Ces couches nous permettent de connecter complètement les unités et nous conduisent au résultat final de la classification. La première couche dense est configurée à 100 unités avec ReLU comme fonction d'activation. La deuxième couche dense, et dernière du modèle, est configurée avec 1 unité et une fonction sigmoïde afin d'obtenir un résultat de classification binaire (0 ou 1).
#
# Le modèle utilise **Adam** comme algorithme d'optimisation, l'entropie croisée binaire comme fonction de perte et la précision pour mesurer la performance du modèle.

# %%
BATCH_SIZE = 1024
EPOCHS = 30

# %% [markdown]
# ## LSTM + Glove

# %% [markdown]
# ### Entrainement du modèle

# %%
# définition du modèle
model_lstm_glv = Sequential(name="lstm_glove")
# layer 1
model_lstm_glv.add(glove_embedding_layer)
model_lstm_glv.add(Dropout(0.2))

# layer 2
model_lstm_glv.add(LSTM(200, dropout=0.2))
model_lstm_glv.add(Dense(100, activation='relu'))

# Output Layer
model_lstm_glv.add(Dense(1, activation="sigmoid"))

print(model_lstm_glv.summary())

model_lstm_glv.compile(optimizer="adam",
                       loss='binary_crossentropy',
                       metrics=['acc', 'AUC',
                                tf.keras.metrics.FalsePositives(name='fp')])
# Out:
# Model: "lstm_glove"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 54, 200)           1977400
#
#  dropout_4 (Dropout)         (None, 54, 200)           0
#
#  lstm (LSTM)                 (None, 200)               320800
#
#  dense_4 (Dense)             (None, 100)               20100
#
#  dense_5 (Dense)             (None, 1)                 101
#
# ...
# Total params: 2,318,401
# Trainable params: 341,001
# Non-trainable params: 1,977,400
# _________________________________________________________________
# None

# %%
# Entrainer le modèle
start = time()
history_lstm = model_lstm_glv.fit(x_train,
                                  y_train,
                                  batch_size=BATCH_SIZE,
                                  epochs=EPOCHS,
                                  validation_split=0.1,
                                  verbose=1,
                                  callbacks=[reduce_lr, callback_tensorboard])
fit_time = (time() - start)
# Out:
# Epoch 1/30
# 6/6 [==============================] - 8s 1s/step - loss: 0.6751 - acc: 0.5884 - auc: 0.6335 - fp: 909.0000 - val_loss: 0.6383 - val_acc: 0.6562 - val_auc: 0.7223 - val_fp: 123.0000 - lr: 0.0010
# Epoch 2/30
# 6/6 [==============================] - 6s 977ms/step - loss: 0.6056 - acc: 0.6894 - auc: 0.7467 - fp: 891.0000 - val_loss: 0.6295 - val_acc: 0.6672 - val_auc: 0.7512 - val_fp: 163.0000 - lr: 0.0010
# Epoch 3/30
# 6/6 [==============================] - 6s 975ms/step - loss: 0.5750 - acc: 0.7049 - auc: 0.7706 - fp: 872.0000 - val_loss: 0.6044 - val_acc: 0.6812 - val_auc: 0.7689 - val_fp: 148.0000 - lr: 0.0010
# Epoch 4/30
# 6/6 [==============================] - 6s 968ms/step - loss: 0.5507 - acc: 0.7248 - auc: 0.7948 - fp: 760.0000 - val_loss: 0.5619 - val_acc: 0.7078 - val_auc: 0.7839 - val_fp: 90.0000 - lr: 0.0010
# Epoch 5/30
# ...

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_lstm = model_lstm_glv.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print("Perte au test : ", evaluation_lstm[0])
print("Accuracy du test:", evaluation_lstm[1])
# Out:
# 2/2 [==============================] - 1s 178ms/step - loss: 0.5623 - acc: 0.7387 - auc: 0.8192 - fp: 161.0000
# Perte au test :  0.5623151659965515
# Accuracy du test: 0.7387499809265137

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_lstm)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_lstm_glv, x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.80      0.75       800
#            1       0.77      0.68      0.72       800
#
#     accuracy                           0.74      1600
#    macro avg       0.74      0.74      0.74      1600
# weighted avg       0.74      0.74      0.74      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'LSTM + GloVe',
        'Faux positifs': '{:0.0f}'.format(evaluation_lstm[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_lstm[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_lstm[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_lstm[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2   SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3             SimpleRNN + FT           340         69.07        63.13
# 4     SimpleRNN + FT + Lemma           354         56.70        55.56
# 5      SimpleRNN + FT + stem           277         58.18        55.19
# 6               LSTM + GloVe           161         81.92        73.87
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0
# 2     71.67                     29.8
# 3     68.81                     27.6
# 4     71.50                     26.3
# 5     70.00                     27.1
# 6     56.23                    187.7

# %%
# Sauvegarde du modèle
model_lstm_glv.save('data/clean/lstm_glove.h5')

# %% [markdown]
# ### Prédiction du modèle

# %%
# décoder la prédiction de score du modèle, pour qu'elle soit 0 ou 1
def decode_prediction(prediction):
    return 'Négatif' if prediction < 0.5 else 'Positif'

# %%
# chargement du modèle
model_lstm_glv = load_model('data/clean/lstm_glove.h5')

# chargement du tokéniseur
with open('data/clean/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# Test du modèle avec une nouvelle requête
tweet = "I told you that she was happy"

# nettoyage du texte de la requête
input_text = clean_tweet(tweet)

# tokéniser et rembourrer la requête test comme dans l'entraînement
input_text = pad_sequences(tokenizer.texts_to_sequences([input_text]),
                           maxlen=max_length)

# obtenir la prédiction du modèle
prediction = model_lstm_glv.predict([input_text])[0]

# obtenir la prédiction de décodage
label = decode_prediction(prediction)

print(f"Tweet : {tweet}")
print(f"Score : {prediction}")
print(f"Label : {label}")
# Out:
# Tweet : I told you that she was happy
# Score : [0.83852756]
# Label : Positif

# %%
# Test du modèle avec une nouvelle requête
tweet = "She is very sad"

# nettoyage du texte de la requête
input_text = clean_tweet(tweet)

# tokéniser et rembourrer la requête test comme dans l'entraînement
input_text = pad_sequences(tokenizer.texts_to_sequences([input_text]),
                           maxlen=max_length)

# obtenir la prédiction du modèle
prediction = model_lstm_glv.predict([input_text])[0]
# obtenir la prédiction de décodage
label = decode_prediction(prediction)

print(f"Tweet : {tweet}")
print(f"Score : {prediction}")
print(f"Label : {label}")
# Out:
# Tweet : She is very sad
# Score : [0.00630224]
# Label : Négatif

# %% [markdown]
# ## LSTM + Glove + Lemma

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_lstm_lem = model_lstm_glv.fit(x_train_lem,
                                      y_train_lem,
                                      batch_size=BATCH_SIZE,
                                      epochs=EPOCHS,
                                      validation_split=0.1,
                                      verbose=0,
                                      callbacks=[reduce_lr, callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_lstm_glv.save('data/clean/lstm_glove_lem.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_lstm_lem = model_lstm_glv.evaluate(x_test_lem, y_test_lem, batch_size=1024)
# Out:
# 2/2 [==============================] - 1s 241ms/step - loss: 0.6512 - acc: 0.6475 - auc: 0.7269 - fp: 375.0000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_lstm_lem)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_lstm_glv, x_test_lem, y_test_lem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.53      0.60       800
#            1       0.62      0.76      0.68       800
#
#     accuracy                           0.65      1600
#    macro avg       0.66      0.65      0.64      1600
# weighted avg       0.66      0.65      0.64      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'LSTM + GloVe + Lemma',
        'Faux positifs': '{:0.0f}'.format(evaluation_lstm_lem[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_lstm_lem[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_lstm_lem[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_lstm_lem[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2   SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3             SimpleRNN + FT           340         69.07        63.13
# 4     SimpleRNN + FT + Lemma           354         56.70        55.56
# 5      SimpleRNN + FT + stem           277         58.18        55.19
# 6               LSTM + GloVe           161         81.92        73.87
# 7       LSTM + GloVe + Lemma           375         72.69        64.75
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0
# 2     71.67                     29.8
# 3     68.81                     27.6
# 4     71.50                     26.3
# 5     70.00                     27.1
# 6     56.23                    187.7
# ...

# %% [markdown]
# ## LSTM + Glove + stem

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_lstm_stem = model_lstm_glv.fit(x_train_stem,
                                       y_train_stem,
                                       batch_size=BATCH_SIZE,
                                       epochs=EPOCHS,
                                       validation_split=0.1,
                                       verbose=0,
                                       callbacks=[reduce_lr, callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_lstm_glv.save('data/clean/lstm_glove_stem.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_lstm_stem = model_lstm_glv.evaluate(x_test_stem, y_test_stem, batch_size=1024)
# Out:
# 2/2 [==============================] - 1s 191ms/step - loss: 0.6773 - acc: 0.6675 - auc: 0.7278 - fp: 334.0000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_lstm_stem)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_lstm_glv, x_test_stem, y_test_stem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64       800
#            1       0.64      0.75      0.69       800
#
#     accuracy                           0.67      1600
#    macro avg       0.67      0.67      0.67      1600
# weighted avg       0.67      0.67      0.67      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'LSTM + GloVe + Stem',
        'Faux positifs': '{:0.0f}'.format(evaluation_lstm_stem[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_lstm_stem[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_lstm_stem[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_lstm_stem[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2   SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3             SimpleRNN + FT           340         69.07        63.13
# 4     SimpleRNN + FT + Lemma           354         56.70        55.56
# 5      SimpleRNN + FT + stem           277         58.18        55.19
# 6               LSTM + GloVe           161         81.92        73.87
# 7       LSTM + GloVe + Lemma           375         72.69        64.75
# 8        LSTM + GloVe + Stem           334         72.78        66.75
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0
# 2     71.67                     29.8
# 3     68.81                     27.6
# 4     71.50                     26.3
# 5     70.00                     27.1
# ...

# %% [markdown]
# ## LSTM avec FastText

# %% [markdown]
# ### Entrainement du modèle

# %%
# définition du modèle
model_lstm_ft = Sequential(name='lstm_fasttext')
# Layer 1
model_lstm_ft.add(ft_embedding_layer)
model_lstm_ft.add(Dropout(0.2))

# Layer 2
model_lstm_ft.add(LSTM(200, dropout=0.2))
model_lstm_ft.add(Dense(100, activation='relu'))

# Output Layer
model_lstm_ft.add(Dense(1, activation="sigmoid"))

model_lstm_ft.summary()
# Out:
# Model: "lstm_fasttext"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_1 (Embedding)     (None, 54, 200)           1977400
#
#  dropout_5 (Dropout)         (None, 54, 200)           0
#
#  lstm_1 (LSTM)               (None, 200)               320800
#
#  dense_6 (Dense)             (None, 100)               20100
#
#  dense_7 (Dense)             (None, 1)                 101
#
# ...
# Total params: 2,318,401
# Trainable params: 341,001
# Non-trainable params: 1,977,400
# _________________________________________________________________

# %%
# Compiler le modèle
model_lstm_ft.compile(optimizer="adam",
                      loss='binary_crossentropy',
                      metrics=['acc', 'AUC',
                               tf.keras.metrics.FalsePositives(name='fp')])

# Entrainer le modèle
start = time()
history_lstm_ft = model_lstm_ft.fit(x_train,
                                    y_train,
                                    batch_size=BATCH_SIZE,
                                    epochs=EPOCHS,
                                    validation_split=0.1,
                                    verbose=0,
                                    callbacks=[reduce_lr, callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_lstm_ft.save('data/clean/lstm_ft.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_lstm_ft = model_lstm_ft.evaluate(x_test_lem, y_test_lem, batch_size=1024)
# Out:
# 2/2 [==============================] - 1s 203ms/step - loss: 0.8321 - acc: 0.4825 - auc: 0.4762 - fp: 375.0000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_lstm_ft)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_lstm_ft, x_test_lem, y_test_lem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.48      0.53      0.51       800
#            1       0.48      0.43      0.46       800
#
#     accuracy                           0.48      1600
#    macro avg       0.48      0.48      0.48      1600
# weighted avg       0.48      0.48      0.48      1600

# %% [markdown]
# ### Sauvegardes des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'LSTM + FT',
        'Faux positifs': '{:0.0f}'.format(evaluation_lstm_ft[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_lstm_ft[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_lstm_ft[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_lstm_ft[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                       Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0          SimpleRNN + GloVe           147         65.44        60.06
# 1  SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2   SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3             SimpleRNN + FT           340         69.07        63.13
# 4     SimpleRNN + FT + Lemma           354         56.70        55.56
# 5      SimpleRNN + FT + stem           277         58.18        55.19
# 6               LSTM + GloVe           161         81.92        73.87
# 7       LSTM + GloVe + Lemma           375         72.69        64.75
# 8        LSTM + GloVe + Stem           334         72.78        66.75
# 9                  LSTM + FT           375         47.62        48.25
#
#   Perte (%) Temps d'entrainement (s)
# 0     74.46                     29.8
# 1     72.97                     27.0
# 2     71.67                     29.8
# 3     68.81                     27.6
# ...

# %% [markdown]
# ## LSTM + FastText + Lemma

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_lstm_ft_lem = model_lstm_ft.fit(x_train_lem,
                                        y_train_lem,
                                        batch_size=BATCH_SIZE,
                                        epochs=EPOCHS,
                                        validation_split=0.1,
                                        verbose=0,
                                        callbacks=[reduce_lr, callback_tensorboard])

fit_time = (time() - start)

# Sauvegarde du modèle
model_lstm_ft.save('data/clean/lstm_ft_lem.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_lstm_ft_lem = model_lstm_ft.evaluate(x_test_lem, y_test_lem, batch_size=1024)
# Out:
# 2/2 [==============================] - 1s 237ms/step - loss: 0.6630 - acc: 0.6231 - auc: 0.6548 - fp: 283.0000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_lstm_ft_lem)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_lstm_ft, x_test_lem, y_test_lem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.63       800
#            1       0.63      0.60      0.61       800
#
#     accuracy                           0.62      1600
#    macro avg       0.62      0.62      0.62      1600
# weighted avg       0.62      0.62      0.62      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'LSTM + FT + Lemma',
        'Faux positifs': '{:0.0f}'.format(evaluation_lstm_ft_lem[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_lstm_ft_lem[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_lstm_ft_lem[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_lstm_ft_lem[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                        Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0           SimpleRNN + GloVe           147         65.44        60.06
# 1   SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2    SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3              SimpleRNN + FT           340         69.07        63.13
# 4      SimpleRNN + FT + Lemma           354         56.70        55.56
# 5       SimpleRNN + FT + stem           277         58.18        55.19
# 6                LSTM + GloVe           161         81.92        73.87
# 7        LSTM + GloVe + Lemma           375         72.69        64.75
# 8         LSTM + GloVe + Stem           334         72.78        66.75
# 9                   LSTM + FT           375         47.62        48.25
# 10          LSTM + FT + Lemma           283         65.48        62.31
#
#    Perte (%) Temps d'entrainement (s)
# 0      74.46                     29.8
# ...

# %% [markdown]
# ## LSTM + FastText + stem

# %% [markdown]
# ### Entrainement du modèle

# %%
# Entrainer le modèle
start = time()
history_lstm_ft_stem = model_lstm_ft.fit(x_train_stem,
                                         y_train_stem,
                                         batch_size=BATCH_SIZE,
                                         epochs=EPOCHS,
                                         validation_split=0.1,
                                         verbose=0,
                                         callbacks=[reduce_lr, callback_tensorboard])
fit_time = (time() - start)

# Sauvegarde du modèle
model_lstm_ft.save('data/clean/lstm_ft_stem.h5')

# %% [markdown]
# ### Évaluation du modèle

# %%
evaluation_lstm_ft_stem = model_lstm_ft.evaluate(x_test_stem, y_test_stem, batch_size=1024)
# Out:
# 2/2 [==============================] - 1s 180ms/step - loss: 0.6722 - acc: 0.6087 - auc: 0.6659 - fp: 362.0000

# %% [markdown]
# ### Visualisation de l'apprentissage

# %%
plot_model(history_lstm_ft_stem)

# %% [markdown]
# ### Résultats du modèle

# %%
plot_confusion_matrix(model_lstm_ft, x_test_stem, y_test_stem)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.55      0.58       800
#            1       0.60      0.67      0.63       800
#
#     accuracy                           0.61      1600
#    macro avg       0.61      0.61      0.61      1600
# weighted avg       0.61      0.61      0.61      1600

# %% [markdown]
# ### Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'LSTM + FT + Stem',
        'Faux positifs': '{:0.0f}'.format(evaluation_lstm_ft_stem[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_lstm_ft_stem[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_lstm_ft_stem[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_lstm_ft_stem[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                        Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0           SimpleRNN + GloVe           147         65.44        60.06
# 1   SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2    SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3              SimpleRNN + FT           340         69.07        63.13
# 4      SimpleRNN + FT + Lemma           354         56.70        55.56
# 5       SimpleRNN + FT + stem           277         58.18        55.19
# 6                LSTM + GloVe           161         81.92        73.87
# 7        LSTM + GloVe + Lemma           375         72.69        64.75
# 8         LSTM + GloVe + Stem           334         72.78        66.75
# 9                   LSTM + FT           375         47.62        48.25
# 10          LSTM + FT + Lemma           283         65.48        62.31
# 11           LSTM + FT + Stem           362         66.59        60.87
#
#    Perte (%) Temps d'entrainement (s)
# ...

# %% [markdown]
# # Bert
#
# BERT (Bidirectional Encoder Representations from Transformers) est un modèle publié par les chercheurs de Google AI Language.
#
# BERT fait appel à Transformer, un mécanisme d'attention qui apprend les relations contextuelles entre les mots (ou les sous-mots) d'un texte. Dans sa forme classique, Transformer comprend deux mécanismes distincts : un encodeur qui lit le texte en entrée et un décodeur qui produit une prédiction pour la tâche. Puisque l'objectif de BERT est de générer un modèle de langage, seul le mécanisme d'encodage est nécessaire. Le fonctionnement détaillé de Transformer est décrit dans un article de Google : https://arxiv.org/pdf/1706.03762.pdf.
#
# Contrairement aux modèles directionnels, qui lisent le texte entré de manière séquentielle (de gauche à droite ou de droite à gauche), l'encodeur Transformer lit la séquence entière de mots en une seule fois. Il est donc considéré comme bidirectionnel. Cette caractéristique permet au modèle d'apprendre le contexte d'un mot en se basant sur tout son environnement (à gauche et à droite du mot).

# %% [markdown]
# ## Entrainement du modèle

# %%
logging.set_verbosity_error()
tokenizer_bert = AutoTokenizer.from_pretrained("bert-base-cased")
bert = TFAutoModel.from_pretrained("bert-base-cased")

# %%
X_test_bert = test_data["cleaned_text"].values
y_test_bert = test_data["target"].values

X_train_bert = train_data["cleaned_text"].values
y_train_bert = train_data["target"].values

# %%
def tokenize(sentence):
    tokens = tokenizer_bert.encode_plus(sentence,
                                        max_length=128,
                                        truncation=True,
                                        padding='max_length',
                                        add_special_tokens=True,
                                        return_attention_mask=True,
                                        return_token_type_ids=False,
                                        return_tensors='tf')
                                        
    return tokens['input_ids'], tokens['attention_mask']


def map_func(input_ids, masks, labels):
    return {'input_ids': input_ids, 'attention_mask': masks}, labels


def bertify_data(data, labels):
    Xids = np.zeros((len(data), 128))
    Xmask = np.zeros((len(data), 128))
    Y = pd.get_dummies(labels).values

    for i, sentence in enumerate(data):
        Xids[i, :], Xmask[i, :] = tokenize(sentence)

    dataset = tf.data.Dataset.from_tensor_slices((Xids, Xmask, Y))

    dataset = dataset.map(map_func)

    return dataset.shuffle(10000).batch(32)

# %%
df_train_bert = bertify_data(X_train_bert, y_train_bert)
df_test_bert = bertify_data(X_test_bert, y_test_bert)

# %%
model_bert = Sequential(name='Bert')

input_ids = tf.keras.layers.Input(shape=(128, ),
                                  name='input_ids',
                                  dtype='int32')
attention_mask = tf.keras.layers.Input(shape=(128, ),
                                       name='attention_mask',
                                       dtype='int32')

embedding_bert = bert(input_ids, attention_mask=attention_mask)[0]

X_bert = tf.keras.layers.GlobalMaxPool1D()(embedding_bert)
X_bert = tf.keras.layers.BatchNormalization()(X_bert)
X_bert = tf.keras.layers.Dense(128, activation='relu')(X_bert)
X_bert = tf.keras.layers.Dropout(0.1)(X_bert)
y_bert = tf.keras.layers.Dense(2, activation='softmax', name='outputs')(X_bert)

model_bert = tf.keras.Model(inputs=[input_ids, attention_mask], outputs=y_bert)

model_bert.layers[2].trainable = False

model_bert.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_ids (InputLayer)         [(None, 128)]        0           []
#
#  attention_mask (InputLayer)    [(None, 128)]        0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  108310272   ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 128,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
# ...

# %%
# Compiler le modèle
model_bert.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['acc', 'AUC',
             tf.keras.metrics.FalsePositives(name='fp')])

# Entrainer le modèle
start = time()
history_bert = model_bert.fit(df_train_bert,
                              epochs=1,
                              verbose=1)
fit_time = (time() - start)

# %% [markdown]
# ## Évaluation du modèle

# %%
evaluation_bert = model_bert.evaluate(df_test_bert)
# Out:
# 50/50 [==============================] - 178s 4s/step - loss: 0.5764 - acc: 0.6988 - auc: 0.7705 - fp: 482.0000

# %% [markdown]
# ## Sauvegarde des résultats dans un tableau

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'Bert',
        'Faux positifs': '{:0.0f}'.format(evaluation_bert[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation_bert[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation_bert[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation_bert[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)
model_history
# Out:
#                        Modèle Faux positifs Score ROC (%) Accuracy (%)  \
# 0           SimpleRNN + GloVe           147         65.44        60.06
# 1   SimpleRNN + GloVe + Lemma           800         51.44        50.00
# 2    SimpleRNN + GloVe + Stem           800         52.63        50.00
# 3              SimpleRNN + FT           340         69.07        63.13
# 4      SimpleRNN + FT + Lemma           354         56.70        55.56
# 5       SimpleRNN + FT + stem           277         58.18        55.19
# 6                LSTM + GloVe           161         81.92        73.87
# 7        LSTM + GloVe + Lemma           375         72.69        64.75
# 8         LSTM + GloVe + Stem           334         72.78        66.75
# 9                   LSTM + FT           375         47.62        48.25
# 10          LSTM + FT + Lemma           283         65.48        62.31
# 11           LSTM + FT + Stem           362         66.59        60.87
# ...

# %% [markdown]
# # Tensorboard

# %%
# %tensorboard --logdir data/logs
# Out:
#       <iframe id="tensorboard-frame-a42d1b9ebf68e903" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-a42d1b9ebf68e903");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# # Optimisation des hyperparamètres pour le meilleur modèle
# https://www.tensorflow.org/tutorials/keras/keras_tuner
#
# https://medium.com/analytics-vidhya/hypertuning-a-lstm-with-keras-tuner-to-forecast-solar-irradiance-7da7577e96eb

# %%
def model_builder(hp):
    model = Sequential()
    model.add(glove_embedding_layer)
    model.add(Dropout(
        hp.Float('Dropout_rate', min_value=0, max_value=0.5, step=0.1)))
    
    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    hp_units = hp.Int('units', min_value=32, max_value=512, step=32)
    model.add(LSTM(units=hp_units))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(1, activation="sigmoid"))
    
    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=hp_learning_rate),
        loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
        metrics=[
            'acc', 'AUC',
             tf.keras.metrics.FalsePositives(name='fp')])

    return model

# %% [markdown]
# Pour instancier le tuner Hyperband, vous devez spécifier l'hypermodèle, l' objective à optimiser et le nombre maximum d'époques à entraîner ( max_epochs ).

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_acc',
                     max_epochs=5,
                     factor=3,
                     directory='lstm tuner',
                     project_name='hyperopti lstm',
                     overwrite=True)

# %% [markdown]
# L'algorithme de réglage Hyperband utilise l'allocation adaptative des ressources et l'arrêt anticipé pour converger rapidement vers un modèle très performant. Cela se fait à l'aide d'un support de style championnat de sport. L'algorithme forme un grand nombre de modèles pour quelques époques et ne reporte que la moitié des modèles les plus performants au tour suivant. Hyperband détermine le nombre de modèles à former dans une fourchette en calculant 1 + factor logarithmique ( max_epochs ) et en l'arrondissant à l'entier supérieur le plus proche.

# %%
# Création d'un rappel pour arrêter la formation plus tôt après avoir atteint
# une certaine valeur pour la perte de validation.
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(x_train, y_train, epochs=30, validation_split=0.1, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
La recherche des hyperparamètres est terminée. Le nombre optimal d'unités dans la première
couche dense connectée est {best_hps.get('units')} et le taux d'apprentissage optimal
pour l'optimiseur est {best_hps.get('learning_rate')}.
""")
# Out:
# Trial 10 Complete [00h 03m 10s]
# val_acc: 0.7562500238418579
#
# Best val_acc So Far: 0.7828124761581421
# Total elapsed time: 00h 20m 28s
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 480 and the optimal learning rate for the optimizer
# is 0.001.

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
model = tuner.hypermodel.build(best_hps)
history = model.fit(x_train, y_train, epochs=30, validation_split=0.1)

val_acc_per_epoch = history.history['val_acc']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch))
# Out:
# Epoch 1/30
# 180/180 [==============================] - 56s 303ms/step - loss: 0.5684 - acc: 0.7007 - auc: 0.7738 - fp: 829.0000 - val_loss: 0.5362 - val_acc: 0.7219 - val_auc: 0.8094 - val_fp: 50.0000
# Epoch 2/30
# 180/180 [==============================] - 53s 297ms/step - loss: 0.4907 - acc: 0.7644 - auc: 0.8426 - fp: 653.0000 - val_loss: 0.5002 - val_acc: 0.7625 - val_auc: 0.8383 - val_fp: 50.0000
# Epoch 3/30
# 180/180 [==============================] - 53s 292ms/step - loss: 0.4404 - acc: 0.7937 - auc: 0.8759 - fp: 570.0000 - val_loss: 0.5006 - val_acc: 0.7625 - val_auc: 0.8444 - val_fp: 89.0000
# Epoch 4/30
# 180/180 [==============================] - 49s 272ms/step - loss: 0.3915 - acc: 0.8139 - auc: 0.9031 - fp: 523.0000 - val_loss: 0.5244 - val_acc: 0.7672 - val_auc: 0.8300 - val_fp: 89.0000
# Epoch 5/30
# ...

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
hypermodel.fit(x_train, y_train, epochs=best_epoch, validation_split=0.1)
# Out:
# Epoch 1/5
# 180/180 [==============================] - 51s 277ms/step - loss: 0.5648 - acc: 0.7089 - auc: 0.7801 - fp: 808.0000 - val_loss: 0.5388 - val_acc: 0.7203 - val_auc: 0.8098 - val_fp: 54.0000
# Epoch 2/5
# 180/180 [==============================] - 52s 288ms/step - loss: 0.4901 - acc: 0.7616 - auc: 0.8435 - fp: 642.0000 - val_loss: 0.5098 - val_acc: 0.7531 - val_auc: 0.8391 - val_fp: 34.0000
# Epoch 3/5
# 180/180 [==============================] - 49s 271ms/step - loss: 0.4445 - acc: 0.7915 - auc: 0.8732 - fp: 566.0000 - val_loss: 0.4988 - val_acc: 0.7703 - val_auc: 0.8388 - val_fp: 66.0000
# Epoch 4/5
# 180/180 [==============================] - 49s 270ms/step - loss: 0.3941 - acc: 0.8201 - auc: 0.9023 - fp: 491.0000 - val_loss: 0.5459 - val_acc: 0.7734 - val_auc: 0.8264 - val_fp: 71.0000
# Epoch 5/5
# ...

# %%
evaluation = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print("Perte au test : ", evaluation[0])
print("Accuracy du test:", evaluation[1])
# Out:
# 2/2 [==============================] - 2s 543ms/step - loss: 2.3391 - acc: 0.7319 - auc: 0.7788 - fp: 228.0000
# Perte au test :  2.339077949523926
# Accuracy du test: 0.7318750023841858

# %%
# Dictionnaire
model_history = model_history.append(
    {
        'Modèle': 'LSTM + GloVe + Hyperoptimisation',
        'Faux positifs': '{:0.0f}'.format(evaluation[3]),
        'Score ROC (%)': '{:0.2f}'.format(evaluation[2] * 100),
        'Accuracy (%)': '{:0.2f}'.format(evaluation[1] * 100),
        'Perte (%)': '{:0.2f}'.format(evaluation[0] * 100),
        "Temps d'entrainement (s)": "{:0.1f}".format(fit_time)
    },
    ignore_index=True)

# Enregistrement
model_history.to_csv('data/clean/resultat.csv', index=False)

# %%
# Sauvegarde du modèle
model.save('data/clean/lstm_glove_hyperopt.h5')

# %%
plot_confusion_matrix(model, x_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.71      0.73       800
#            1       0.72      0.75      0.74       800
#
#     accuracy                           0.73      1600
#    macro avg       0.73      0.73      0.73      1600
# weighted avg       0.73      0.73      0.73      1600

# %% [markdown]
# # Comparaison des résultats

# %%
resultats_modeles = pd.read_csv("data/clean/resultat.csv")
designer_resultat = pd.read_csv("data/clean/designer_resultat.csv")
cognitive_resultat = pd.read_csv("data/clean/cognitive_services_resultat.csv")
resultats_modeles = pd.concat([resultats_modeles, designer_resultat, cognitive_resultat])

resultats_modeles
# Out:
#                               Modèle  Faux positifs  Score ROC (%)  \
# 0                  SimpleRNN + GloVe            773          70.22
# 1          SimpleRNN + GloVe + Lemma            800          53.32
# 2           SimpleRNN + GloVe + Stem            687          53.47
# 3                     SimpleRNN + FT            340          69.07
# 4             SimpleRNN + FT + Lemma            354          56.70
# 5              SimpleRNN + FT + stem            277          58.18
# 6                       LSTM + GloVe            280          81.47
# 7               LSTM + GloVe + Lemma            399          70.42
# 8                LSTM + GloVe + Stem            390          72.11
# 9                          LSTM + FT            375          47.62
# 10                 LSTM + FT + Lemma            283          65.48
# 11                  LSTM + FT + Stem            362          66.59
# 12                              Bert            482          77.05
# ...

# %%
pd.options.plotting.backend = "plotly"

# %%
resultats_modeles.plot.barh(
    y='Modèle',
    x=["Faux positifs", "Score ROC (%)", "Accuracy (%)", "Perte (%)", "Temps d'entrainement (s)"],
    text_auto='.2s',
#     barmode='group'
)
# Out:
# <div>                            <div id="b8cffb23-23c1-49de-8ced-45b5becc6c50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8cffb23-23c1-49de-8ced-45b5becc6c50")) {                    Plotly.newPlot(                        "b8cffb23-23c1-49de-8ced-45b5becc6c50",                        [{"alignmentgroup":"True","hovertemplate":"variable=Faux positifs<br>value=%{x}<br>Mod\u00e8le=%{y}<extra></extra>","legendgroup":"Faux positifs","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Faux positifs","offsetgroup":"Faux positifs","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x:.2s}","x":[773.0,800.0,687.0,340.0,354.0,277.0,280.0,399.0,390.0,375.0,283.0,362.0,482.0,228.0,261.0,416.0],"xaxis":"x","y":["SimpleRNN + G
# ...

# %% [markdown]
# Avec l'hyperoptimisation pour le LSTM, on a un meilleur accuracy ainsi que moins de faux positifs. En revanche, le temps d'entraînement est plus long. On peut encore largement améliorer les hyperparamètres mais le temps et les ressources nécéssaires sont à prendre en compte.

# %% [markdown]
# # Conclusion
#
# L'analyse des sentiments n'est pas une tâche facile, comme c'est le cas pour le traitement du langage naturel. Les tweets ont tendance à être bruités et à utiliser de nombreuses formes différentes pour les mots, ce qui peut constituer un problème pour leur analyse. Cependant, la quantité de données et le prétraitement des données ont beaucoup aidé ce projet à obtenir de bons résultats.
#
# Les prédictions obtenues avec les nouvelles données sont précises par rapport au contenu des tweets, ce qui signifie que le modèle fonctionne bien avec une précision de ~74%. Il est également intéressant de noter que les combinaisons **stem/glove** et **lemma/glove** sont moins performantes que le **glove sans traitement de texte**. En revanche, pour la méthode **fasttext**, la lemmatisation ou la stemmatisation **améliorent le modèle LSTM**.
#
# Le modèle pourrait être amélioré en ajoutant de nouvelles techniques de prétraitement des données et avec d'autres architectures de modèles recommandées pour l'analyse des sentiments comme les **LSTM bidirectionnels**.
